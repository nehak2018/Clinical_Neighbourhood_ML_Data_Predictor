# %%
import pandas as pd
import numpy as np
from pathlib import Path


# ============================================================
# 1. FILE PATHS
# ============================================================

BASE_DIR = Path().resolve().parent

DATA_DIR = (
    BASE_DIR
    / "data"
    / "2015_2016"
    / "Dietary"
)

xpt_file = DATA_DIR / "DR1TOT_I.xpt"
csv_file = DATA_DIR / "DR1TOT_I_corrected.csv"


# ============================================================
# 2. READ ORIGINAL XPT
# ============================================================

df = pd.read_sas(
    xpt_file,
    format="xport",
    encoding="latin1"
)

#
# Preserve completely untouched pandas-decoded source.
#
source_df = df.copy()


print("=" * 100)
print("NHANES 2015-2016 DR1TOT_I XPT -> CSV")
print("=" * 100)

print(
    "Rows:",
    f"{len(df):,}"
)

print(
    "Columns:",
    len(df.columns)
)


# ============================================================
# 3. EXPECTED STRUCTURE
# ============================================================

EXPECTED_COLUMNS = [
    "SEQN",
    "WTDRD1",
    "WTDR2D",
    "DR1DRSTZ",
    "DR1EXMER",
    "DRABF",
    "DRDINT",
    "DR1DBIH",
    "DR1DAY",
    "DR1LANG",
    "DR1MRESP",
    "DR1HELP",
    "DBQ095Z",
    "DBD100",
    "DRQSPREP",
    "DR1STY",
    "DR1SKY",
    "DRQSDIET",
    "DRQSDT1",
    "DRQSDT2",
    "DRQSDT3",
    "DRQSDT4",
    "DRQSDT5",
    "DRQSDT6",
    "DRQSDT7",
    "DRQSDT8",
    "DRQSDT9",
    "DRQSDT10",
    "DRQSDT11",
    "DRQSDT12",
    "DRQSDT91",
    "DR1TNUMF",
    "DR1TKCAL",
    "DR1TPROT",
    "DR1TCARB",
    "DR1TSUGR",
    "DR1TFIBE",
    "DR1TTFAT",
    "DR1TSFAT",
    "DR1TMFAT",
    "DR1TPFAT",
    "DR1TCHOL",
    "DR1TATOC",
    "DR1TATOA",
    "DR1TRET",
    "DR1TVARA",
    "DR1TACAR",
    "DR1TBCAR",
    "DR1TCRYP",
    "DR1TLYCO",
    "DR1TLZ",
    "DR1TVB1",
    "DR1TVB2",
    "DR1TNIAC",
    "DR1TVB6",
    "DR1TFOLA",
    "DR1TFA",
    "DR1TFF",
    "DR1TFDFE",
    "DR1TCHL",
    "DR1TVB12",
    "DR1TB12A",
    "DR1TVC",
    "DR1TVD",
    "DR1TVK",
    "DR1TCALC",
    "DR1TPHOS",
    "DR1TMAGN",
    "DR1TIRON",
    "DR1TZINC",
    "DR1TCOPP",
    "DR1TSODI",
    "DR1TPOTA",
    "DR1TSELE",
    "DR1TCAFF",
    "DR1TTHEO",
    "DR1TALCO",
    "DR1TMOIS",
    "DR1TS040",
    "DR1TS060",
    "DR1TS080",
    "DR1TS100",
    "DR1TS120",
    "DR1TS140",
    "DR1TS160",
    "DR1TS180",
    "DR1TM161",
    "DR1TM181",
    "DR1TM201",
    "DR1TM221",
    "DR1TP182",
    "DR1TP183",
    "DR1TP184",
    "DR1TP204",
    "DR1TP205",
    "DR1TP225",
    "DR1TP226",
    "DR1_300",
    "DR1_320Z",
    "DR1_330Z",
    "DR1BWATZ",
    "DR1TWS",
    "DRD340",
    "DRD350A",
    "DRD350AQ",
    "DRD350B",
    "DRD350BQ",
    "DRD350C",
    "DRD350CQ",
    "DRD350D",
    "DRD350DQ",
    "DRD350E",
    "DRD350EQ",
    "DRD350F",
    "DRD350FQ",
    "DRD350G",
    "DRD350GQ",
    "DRD350H",
    "DRD350HQ",
    "DRD350I",
    "DRD350IQ",
    "DRD350J",
    "DRD350JQ",
    "DRD350K",
    "DRD360",
    "DRD370A",
    "DRD370AQ",
    "DRD370B",
    "DRD370BQ",
    "DRD370C",
    "DRD370CQ",
    "DRD370D",
    "DRD370DQ",
    "DRD370E",
    "DRD370EQ",
    "DRD370F",
    "DRD370FQ",
    "DRD370G",
    "DRD370GQ",
    "DRD370H",
    "DRD370HQ",
    "DRD370I",
    "DRD370IQ",
    "DRD370J",
    "DRD370JQ",
    "DRD370K",
    "DRD370KQ",
    "DRD370L",
    "DRD370LQ",
    "DRD370M",
    "DRD370MQ",
    "DRD370N",
    "DRD370NQ",
    "DRD370O",
    "DRD370OQ",
    "DRD370P",
    "DRD370PQ",
    "DRD370Q",
    "DRD370QQ",
    "DRD370R",
    "DRD370RQ",
    "DRD370S",
    "DRD370SQ",
    "DRD370T",
    "DRD370TQ",
    "DRD370U",
    "DRD370UQ",
    "DRD370V"
]


if df.columns.tolist() != EXPECTED_COLUMNS:

    raise ValueError(
        "DR1TOT_I columns/order differ.\n\n"
        f"Expected:\n{EXPECTED_COLUMNS}\n\n"
        f"Actual:\n{df.columns.tolist()}"
    )


if len(df) != 9544:

    raise ValueError(
        f"Unexpected row count: {len(df):,}"
    )


if len(df.columns) != 168:

    raise ValueError(
        f"Unexpected column count: {len(df.columns)}"
    )


print(
    "PASS: Structure = 9,544 rows x 168 columns."
)


# ============================================================
# 4. DEFINE GENUINE DIETARY DECIMAL VARIABLES
# ============================================================

#
# These 50 fields contain genuine fractional values.
#
# THEY MUST REMAIN FLOATING POINT.
#
# NEVER:
#
#     .round()
#     astype(Int64)
#     float_format=
#
# on these variables.
#

DECIMAL_COLUMNS = [
    "WTDRD1",
    "WTDR2D",
    "DR1TPROT",
    "DR1TCARB",
    "DR1TSUGR",
    "DR1TFIBE",
    "DR1TTFAT",
    "DR1TSFAT",
    "DR1TMFAT",
    "DR1TPFAT",
    "DR1TATOC",
    "DR1TATOA",
    "DR1TVB1",
    "DR1TVB2",
    "DR1TNIAC",
    "DR1TVB6",
    "DR1TCHL",
    "DR1TVB12",
    "DR1TB12A",
    "DR1TVC",
    "DR1TVD",
    "DR1TVK",
    "DR1TIRON",
    "DR1TZINC",
    "DR1TCOPP",
    "DR1TSELE",
    "DR1TALCO",
    "DR1TMOIS",
    "DR1TS040",
    "DR1TS060",
    "DR1TS080",
    "DR1TS100",
    "DR1TS120",
    "DR1TS140",
    "DR1TS160",
    "DR1TS180",
    "DR1TM161",
    "DR1TM181",
    "DR1TM201",
    "DR1TM221",
    "DR1TP182",
    "DR1TP183",
    "DR1TP184",
    "DR1TP204",
    "DR1TP205",
    "DR1TP225",
    "DR1TP226",
    "DR1_320Z",
    "DR1_330Z",
    "DR1BWATZ"
]


INTEGER_COLUMNS = [
    col
    for col in EXPECTED_COLUMNS
    if col not in DECIMAL_COLUMNS
]


if len(DECIMAL_COLUMNS) != 50:

    raise ValueError(
        "Expected exactly 50 decimal fields."
    )


if len(INTEGER_COLUMNS) != 118:

    raise ValueError(
        "Expected exactly 118 integer/code fields."
    )


print("\n--- FIELD TYPE PLAN ---")

print(
    "Genuine Dietary decimal fields:",
    len(DECIMAL_COLUMNS)
)

print(
    "Whole-number/code fields:",
    len(INTEGER_COLUMNS)
)


# ============================================================
# 5. CHECK KNOWN XPORT TINY-ZERO ARTIFACT
# ============================================================

#
# Known SAS XPORT zero-decoding value:
#
#     5.397605346934028e-79
#
# Never blanket replace this before validating the
# variable/count pattern.
#

TINY_VALUE = np.float64(
    5.397605346934028e-79
)


numeric_cols = (
    df.select_dtypes(
        include=[np.number]
    )
    .columns
    .tolist()
)


if numeric_cols != EXPECTED_COLUMNS:

    raise ValueError(
        "Expected all 168 variables "
        "to load numerically."
    )


tiny_counts = (
    df[numeric_cols]
    .eq(TINY_VALUE)
    .sum()
)


tiny_total = int(
    tiny_counts.sum()
)


tiny_variable_count = int(
    tiny_counts.gt(0)
    .sum()
)


true_zero_counts = (
    df[numeric_cols]
    .eq(0)
    .sum()
)


true_zero_total = int(
    true_zero_counts.sum()
)


print("\n--- ORIGINAL XPT ZERO CHECK ---")

print(
    "Ordinary numeric zeros before correction:",
    f"{true_zero_total:,}"
)

print(
    "Tiny XPORT artifacts:",
    f"{tiny_total:,}"
)

print(
    "Variables containing tiny artifacts:",
    tiny_variable_count
)


print("\nTiny values by variable:")

print(
    tiny_counts[
        tiny_counts > 0
    ]
    .sort_values(
        ascending=False
    )
    .to_string()
)


# ============================================================
# 6. VALIDATE EXACT TINY-ZERO PATTERN
# ============================================================

EXPECTED_TINY_COUNTS = {
    "WTDRD1": 1038,
    "WTDR2D": 1479,
    "DR1DBIH": 469,
    "DR1TNUMF": 1,
    "DR1TKCAL": 1,
    "DR1TPROT": 2,
    "DR1TCARB": 1,
    "DR1TSUGR": 1,
    "DR1TFIBE": 70,
    "DR1TTFAT": 2,
    "DR1TSFAT": 2,
    "DR1TMFAT": 2,
    "DR1TPFAT": 2,
    "DR1TCHOL": 101,
    "DR1TATOC": 2,
    "DR1TATOA": 6950,
    "DR1TRET": 47,
    "DR1TVARA": 6,
    "DR1TACAR": 1045,
    "DR1TBCAR": 99,
    "DR1TCRYP": 770,
    "DR1TLYCO": 2114,
    "DR1TLZ": 84,
    "DR1TVB1": 2,
    "DR1TVB2": 2,
    "DR1TNIAC": 2,
    "DR1TVB6": 2,
    "DR1TFOLA": 2,
    "DR1TFA": 254,
    "DR1TFF": 71,
    "DR1TFDFE": 2,
    "DR1TCHL": 2,
    "DR1TVB12": 19,
    "DR1TB12A": 5641,
    "DR1TVC": 42,
    "DR1TVD": 196,
    "DR1TVK": 3,
    "DR1TCALC": 1,
    "DR1TPHOS": 1,
    "DR1TMAGN": 1,
    "DR1TIRON": 2,
    "DR1TZINC": 1,
    "DR1TCOPP": 1,
    "DR1TSODI": 1,
    "DR1TPOTA": 1,
    "DR1TSELE": 2,
    "DR1TCAFF": 2283,
    "DR1TTHEO": 4525,
    "DR1TALCO": 7226,
    "DR1TMOIS": 1,
    "DR1TS040": 332,
    "DR1TS060": 337,
    "DR1TS080": 108,
    "DR1TS100": 22,
    "DR1TS120": 15,
    "DR1TS140": 4,
    "DR1TS160": 2,
    "DR1TS180": 3,
    "DR1TM161": 11,
    "DR1TM181": 2,
    "DR1TM201": 36,
    "DR1TM221": 1147,
    "DR1TP182": 2,
    "DR1TP183": 2,
    "DR1TP184": 3808,
    "DR1TP204": 72,
    "DR1TP205": 1046,
    "DR1TP225": 732,
    "DR1TP226": 1342,
    "DR1_320Z": 1787,
    "DR1_330Z": 4757,
    "DR1BWATZ": 4925
}


actual_tiny_counts = (
    tiny_counts[
        tiny_counts > 0
    ]
    .astype(int)
    .to_dict()
)


if actual_tiny_counts != EXPECTED_TINY_COUNTS:

    raise ValueError(
        "STOP: Tiny-value pattern differs from "
        "validated DR1TOT_I attachment.\n\n"
        f"Expected:\n{EXPECTED_TINY_COUNTS}\n\n"
        f"Actual:\n{actual_tiny_counts}"
    )


if tiny_total != 55066:

    raise ValueError(
        f"Unexpected tiny-value total: "
        f"{tiny_total:,}"
    )


if tiny_variable_count != 72:

    raise ValueError(
        "Expected tiny values in exactly 72 variables."
    )


if true_zero_total != 0:

    raise ValueError(
        "Unexpected ordinary zero values existed "
        "before correction."
    )


print(
    "\nPASS: Exact 55,066 tiny-zero artifacts "
    "across 72 variables validated."
)


# ============================================================
# 7. RESTORE ONLY VALIDATED ZEROS
# ============================================================

#
# DO NOT:
#
#     df.replace(TINY_VALUE, 0)
#
# globally.
#

print(
    "\n--- VALIDATED ZERO RESTORATION ---"
)


correction_total = 0


for col, expected_count in EXPECTED_TINY_COUNTS.items():

    mask = (
        df[col]
        .eq(TINY_VALUE)
    )


    actual_count = int(
        mask.sum()
    )


    if actual_count != expected_count:

        raise ValueError(
            f"{col}: expected "
            f"{expected_count:,}, "
            f"found {actual_count:,}."
        )


    df.loc[
        mask,
        col
    ] = 0


    correction_total += actual_count


if correction_total != 55066:

    raise ValueError(
        "Incorrect total zero-restoration count."
    )


print(
    "PASS:",
    f"{correction_total:,}",
    "validated zero values restored."
)


# ============================================================
# 8. CREATE EXPECTED CORRECTED SOURCE COPY
# ============================================================

#
# This is the exact corrected XPT representation against
# which all subsequent transformations are compared.
#

expected_df = source_df.copy()


for col in EXPECTED_TINY_COUNTS:

    expected_df.loc[
        expected_df[col]
        .eq(TINY_VALUE),
        col
    ] = 0


# ============================================================
# 9. CONFIRM NO TINY VALUES REMAIN
# ============================================================

remaining_tiny = int(
    df[numeric_cols]
    .eq(TINY_VALUE)
    .sum()
    .sum()
)


print(
    "\nTiny values remaining:",
    remaining_tiny
)


if remaining_tiny != 0:

    raise ValueError(
        "Tiny XPORT artifacts remain after correction."
    )


print(
    "PASS: No tiny XPORT artifacts remain."
)


# ============================================================
# 10. DETECT GENUINE DECIMAL VARIABLES
# ============================================================

#
# This runs BEFORE Int64 conversion.
#
# np.round() is ONLY used to test whether a value
# contains a fractional component.
#
# The dataframe itself is NOT rounded.
#

print(
    "\n--- GENUINE DECIMAL DETECTION ---"
)


detected_decimal_columns = []


for col in numeric_cols:

    values = (
        df[col]
        .dropna()
        .to_numpy(
            dtype=float
        )
    )


    if len(values) == 0:
        continue


    fractional_mask = ~np.isclose(
        values,
        np.round(values),
        rtol=0,
        atol=1e-12
    )


    fractional_count = int(
        fractional_mask.sum()
    )


    if fractional_count > 0:

        detected_decimal_columns.append(
            col
        )


        print(
            f"{col}: "
            f"{fractional_count:,} fractional observations"
        )


if detected_decimal_columns != DECIMAL_COLUMNS:

    raise ValueError(
        "STOP: Genuine decimal-variable pattern differs.\n\n"
        f"Expected:\n{DECIMAL_COLUMNS}\n\n"
        f"Actual:\n{detected_decimal_columns}"
    )


print(
    "\nPASS: Exactly 50 genuine Dietary "
    "decimal fields detected."
)


# ============================================================
# 11. CLEAN AND VALIDATE SEQN
# ============================================================

seqn_values = (
    df["SEQN"]
    .dropna()
    .to_numpy(
        dtype=float
    )
)


if not np.isclose(
    seqn_values,
    np.round(
        seqn_values
    ),
    rtol=0,
    atol=1e-12
).all():

    raise ValueError(
        "SEQN contains unexpected fractional values."
    )


df["SEQN"] = (
    df["SEQN"]
    .astype("Int64")
)


print("\n--- SEQN ---")

print(
    "Minimum:",
    df["SEQN"].min()
)

print(
    "Maximum:",
    df["SEQN"].max()
)

print(
    "Missing:",
    int(
        df["SEQN"]
        .isna()
        .sum()
    )
)

print(
    "Duplicates:",
    int(
        df["SEQN"]
        .duplicated()
        .sum()
    )
)


if df["SEQN"].min() != 83732:

    raise ValueError(
        "Unexpected minimum SEQN."
    )


if df["SEQN"].max() != 93702:

    raise ValueError(
        "Unexpected maximum SEQN."
    )


if int(
    df["SEQN"]
    .isna()
    .sum()
) != 0:

    raise ValueError(
        "Missing SEQN found."
    )


if int(
    df["SEQN"]
    .duplicated()
    .sum()
) != 0:

    raise ValueError(
        "Duplicate SEQN found."
    )


print(
    "PASS: SEQN 83732-93702 validated."
)


# ============================================================
# 12. CONVERT ONLY PROVEN WHOLE-NUMBER FIELDS TO Int64
# ============================================================

#
# 118 fields become nullable Int64.
#
# 50 genuine Dietary decimal fields remain untouched.
#
# NO round() is used during conversion.
#

for col in INTEGER_COLUMNS:

    values = (
        df[col]
        .dropna()
        .to_numpy(
            dtype=float
        )
    )


    if len(values) > 0:

        whole_mask = np.isclose(
            values,
            np.round(values),
            rtol=0,
            atol=1e-12
        )


        if not whole_mask.all():

            raise ValueError(
                f"{col} unexpectedly contains "
                "fractional values."
            )


    df[col] = (
        df[col]
        .astype("Int64")
    )


print(
    "\nPASS: 118 whole-number/code fields "
    "converted to nullable Int64."
)


print(
    "PASS: All 50 genuine Dietary decimal "
    "fields remain floating-point and unchanged."
)


# ============================================================
# 13. WTDRD1 - EXACT XPT + CDC DISPLAY CHECK
# ============================================================

#
# CDC webpage displays:
#
#     1974.178694 to 454277.71731
#
# Actual XPT contains:
#
#     minimum = 1974.178694
#     maximum = 454277.717307
#
# The XPT has MORE precision than the CDC HTML display.
#
# We preserve:
#
#     454277.717307
#
# exactly.
#

wtdrd1_positive = int(
    df["WTDRD1"]
    .gt(0)
    .sum()
)


wtdrd1_zero = int(
    df["WTDRD1"]
    .eq(0)
    .sum()
)


wtdrd1_missing = int(
    df["WTDRD1"]
    .isna()
    .sum()
)


positive_wtdrd1 = (
    df.loc[
        df["WTDRD1"] > 0,
        "WTDRD1"
    ]
)


actual_wtdrd1_min = float(
    positive_wtdrd1.min()
)


actual_wtdrd1_max = float(
    positive_wtdrd1.max()
)


print(
    "\n--- WTDRD1 ---"
)

print(
    "Positive:",
    f"{wtdrd1_positive:,}"
)

print(
    "Zero:",
    f"{wtdrd1_zero:,}"
)

print(
    "Missing:",
    f"{wtdrd1_missing:,}"
)

print(
    "Actual XPT minimum:",
    repr(actual_wtdrd1_min)
)

print(
    "Actual XPT maximum:",
    repr(actual_wtdrd1_max)
)


if wtdrd1_positive != 8506:

    raise ValueError(
        "WTDRD1 positive count differs."
    )


if wtdrd1_zero != 1038:

    raise ValueError(
        "WTDRD1 zero count differs."
    )


if wtdrd1_missing != 0:

    raise ValueError(
        "WTDRD1 unexpectedly contains missing values."
    )


#
# Exact XPT fidelity.
#

if actual_wtdrd1_min != 1974.178694:

    raise ValueError(
        "WTDRD1 exact XPT minimum differs."
    )


if actual_wtdrd1_max != 454277.717307:

    raise ValueError(
        "WTDRD1 exact XPT maximum differs."
    )


#
# Secondary CDC DISPLAY validation only.
#
# These round() calls operate on temporary scalar values.
#
# THEY DO NOT MODIFY THE DATAFRAME.
#

if round(
    actual_wtdrd1_min,
    6
) != 1974.178694:

    raise ValueError(
        "WTDRD1 minimum does not match "
        "CDC displayed precision."
    )


if round(
    actual_wtdrd1_max,
    5
) != 454277.71731:

    raise ValueError(
        "WTDRD1 maximum does not match "
        "CDC displayed precision."
    )


print(
    "PASS: WTDRD1 exact XPT values preserved."
)

print(
    "PASS: WTDRD1 matches CDC displayed range "
    "without changing source precision."
)


# ============================================================
# 14. WTDR2D - EXACT XPT CHECK
# ============================================================

#
# Actual attached XPT:
#
# positive minimum = 1663.514111
# positive maximum = 579148.95623
#
# These happen to match CDC display precision exactly.
#

wtdr2d_positive = int(
    df["WTDR2D"]
    .gt(0)
    .sum()
)


wtdr2d_zero = int(
    df["WTDR2D"]
    .eq(0)
    .sum()
)


wtdr2d_missing = int(
    df["WTDR2D"]
    .isna()
    .sum()
)


positive_wtdr2d = (
    df.loc[
        df["WTDR2D"] > 0,
        "WTDR2D"
    ]
)


actual_wtdr2d_min = float(
    positive_wtdr2d.min()
)


actual_wtdr2d_max = float(
    positive_wtdr2d.max()
)


print(
    "\n--- WTDR2D ---"
)

print(
    "Positive:",
    f"{wtdr2d_positive:,}"
)

print(
    "Zero:",
    f"{wtdr2d_zero:,}"
)

print(
    "Missing:",
    f"{wtdr2d_missing:,}"
)

print(
    "Actual XPT minimum:",
    repr(actual_wtdr2d_min)
)

print(
    "Actual XPT maximum:",
    repr(actual_wtdr2d_max)
)


if wtdr2d_positive != 7027:

    raise ValueError(
        "WTDR2D positive count differs."
    )


if wtdr2d_zero != 1479:

    raise ValueError(
        "WTDR2D zero count differs."
    )


if wtdr2d_missing != 1038:

    raise ValueError(
        "WTDR2D missing count differs."
    )


if actual_wtdr2d_min != 1663.514111:

    raise ValueError(
        "WTDR2D exact XPT minimum differs."
    )


if actual_wtdr2d_max != 579148.95623:

    raise ValueError(
        "WTDR2D exact XPT maximum differs."
    )


print(
    "PASS: WTDR2D exact XPT range validated."
)


# ============================================================
# 15. CDC CHECK - DR1DRSTZ
# ============================================================

EXPECTED_DR1DRSTZ = {
    1: 8327,
    2: 110,
    4: 179,
    5: 928
}


actual_dr1drstz = (
    df["DR1DRSTZ"]
    .value_counts()
    .sort_index()
    .to_dict()
)


print(
    "\n--- DR1DRSTZ ---"
)

print(
    actual_dr1drstz
)


if actual_dr1drstz != EXPECTED_DR1DRSTZ:

    raise ValueError(
        "DR1DRSTZ frequencies differ."
    )


if int(
    df["DR1DRSTZ"]
    .isna()
    .sum()
) != 0:

    raise ValueError(
        "Unexpected missing DR1DRSTZ."
    )


print(
    "PASS: DR1DRSTZ matches CDC."
)


# ============================================================
# 16. CDC CHECK - DRDINT
# ============================================================

EXPECTED_DRDINT = {
    1: 1479,
    2: 7027
}


actual_drdint = (
    df["DRDINT"]
    .value_counts()
    .sort_index()
    .to_dict()
)


if actual_drdint != EXPECTED_DRDINT:

    raise ValueError(
        "DRDINT frequencies differ."
    )


if int(
    df["DRDINT"]
    .isna()
    .sum()
) != 1038:

    raise ValueError(
        "DRDINT missing count differs."
    )


print(
    "PASS: DRDINT matches CDC."
)


# ============================================================
# 17. DRDINT / WTDR2D CONSISTENCY
# ============================================================

#
# DRDINT = 2:
#     two days of intake
#
# Should correspond exactly to positive WTDR2D.
#

two_days = (
    df["DRDINT"]
    .eq(2)
    .fillna(False)
    .to_numpy(
        dtype=bool
    )
)


positive_two_day_weight = (
    df["WTDR2D"]
    .gt(0)
    .fillna(False)
    .to_numpy(
        dtype=bool
    )
)


two_day_mismatch = int(
    np.sum(
        two_days
        !=
        positive_two_day_weight
    )
)


print(
    "\n--- DRDINT / WTDR2D ROUTING ---"
)

print(
    "Mismatches:",
    two_day_mismatch
)


if two_day_mismatch != 0:

    raise ValueError(
        "DRDINT=2 and positive WTDR2D "
        "do not match exactly."
    )


print(
    "PASS: DRDINT=2 exactly matches "
    "positive WTDR2D."
)


# ============================================================
# 18. CDC CHECK - DR1DBIH
# ============================================================

#
# Days between dietary intake and household interview.
#
# Allowed range:
#
#     -32 to 70
#
# Includes legitimate zero.
#

dr1dbih_range = int(
    df["DR1DBIH"]
    .between(
        -32,
        70
    )
    .sum()
)


dr1dbih_zero = int(
    df["DR1DBIH"]
    .eq(0)
    .sum()
)


dr1dbih_missing = int(
    df["DR1DBIH"]
    .isna()
    .sum()
)


if dr1dbih_range != 8413:

    raise ValueError(
        "DR1DBIH range count differs."
    )


if dr1dbih_zero != 469:

    raise ValueError(
        "DR1DBIH zero count differs."
    )


if dr1dbih_missing != 1131:

    raise ValueError(
        "DR1DBIH missing count differs."
    )


print(
    "PASS: DR1DBIH range/zero pattern validated."
)


# ============================================================
# 19. CDC CHECK - DR1TNUMF
# ============================================================

#
# Number of foods/beverages reported.
#

dr1tnumf_range = int(
    df["DR1TNUMF"]
    .between(
        0,
        45
    )
    .sum()
)


dr1tnumf_zero = int(
    df["DR1TNUMF"]
    .eq(0)
    .sum()
)


dr1tnumf_missing = int(
    df["DR1TNUMF"]
    .isna()
    .sum()
)


if dr1tnumf_range != 8506:

    raise ValueError(
        "DR1TNUMF range count differs."
    )


if dr1tnumf_zero != 1:

    raise ValueError(
        "DR1TNUMF zero count differs."
    )


if dr1tnumf_missing != 1038:

    raise ValueError(
        "DR1TNUMF missing count differs."
    )


print(
    "PASS: DR1TNUMF validated."
)


# ============================================================
# 20. DEFINE 65 NUTRIENT / COMPONENT VARIABLES
# ============================================================

start_index = EXPECTED_COLUMNS.index(
    "DR1TKCAL"
)


end_index = EXPECTED_COLUMNS.index(
    "DR1TP226"
)


NUTRIENT_COLUMNS = (
    EXPECTED_COLUMNS[
        start_index:
        end_index + 1
    ]
)


if len(NUTRIENT_COLUMNS) != 65:

    raise ValueError(
        "Expected exactly 65 nutrient/component fields."
    )


print(
    "\nNutrient/component fields:",
    len(NUTRIENT_COLUMNS)
)


# ============================================================
# 21. NUTRIENT COMPLETENESS CHECK
# ============================================================

#
# Reliable Day-1 recall:
#
#     DR1DRSTZ = 1
#     n = 8,327
#
# Each total nutrient variable should have:
#
#     8,327 nonmissing
#     1,217 missing
#

nutrient_completeness_errors = {}


for col in NUTRIENT_COLUMNS:

    nonmissing_count = int(
        df[col]
        .notna()
        .sum()
    )


    missing_count = int(
        df[col]
        .isna()
        .sum()
    )


    if not (
        nonmissing_count == 8327
        and
        missing_count == 1217
    ):

        nutrient_completeness_errors[col] = {
            "nonmissing": nonmissing_count,
            "missing": missing_count
        }


if nutrient_completeness_errors:

    raise ValueError(
        "Nutrient completeness differs:\n"
        + str(
            nutrient_completeness_errors
        )
    )


print(
    "PASS: All 65 nutrient fields contain "
    "8,327 nonmissing and 1,217 missing values."
)


# ============================================================
# 22. SELECTED VALID ZERO COUNTS
# ============================================================

#
# Demonstrates why tiny values must become zero,
# not NaN/missing.
#

SELECTED_ZERO_COUNTS = {
    "DR1TKCAL": 1,
    "DR1TATOA": 6950,
    "DR1TB12A": 5641,
    "DR1TCAFF": 2283,
    "DR1TTHEO": 4525,
    "DR1TALCO": 7226
}


print(
    "\n--- SELECTED ZERO COUNTS ---"
)


for col, expected_count in SELECTED_ZERO_COUNTS.items():

    actual_count = int(
        df[col]
        .eq(0)
        .sum()
    )


    print(
        f"{col}:",
        f"{actual_count:,}"
    )


    if actual_count != expected_count:

        raise ValueError(
            f"{col}: zero count differs."
        )


print(
    "PASS: Selected nutrient zero counts validated."
)


# ============================================================
# 23. WATER VARIABLES
# ============================================================

#
# These three are genuine decimal Dietary fields.
#
# They MUST remain float.
#
# CDC ranges include zero.
#

WATER_CHECKS = {
    "DR1_320Z": {
        "low": 0,
        "high": 11520,
        "nonmissing": 8506,
        "missing": 1038,
        "zero": 1787
    },

    "DR1_330Z": {
        "low": 0,
        "high": 11520,
        "nonmissing": 8506,
        "missing": 1038,
        "zero": 4757
    },

    "DR1BWATZ": {
        "low": 0,
        "high": 9630,
        "nonmissing": 8506,
        "missing": 1038,
        "zero": 4925
    }
}


print(
    "\n--- WATER VARIABLE CHECK ---"
)


for col, info in WATER_CHECKS.items():

    range_count = int(
        df[col]
        .between(
            info["low"],
            info["high"]
        )
        .sum()
    )


    missing_count = int(
        df[col]
        .isna()
        .sum()
    )


    zero_count = int(
        df[col]
        .eq(0)
        .sum()
    )


    print(
        f"{col}: "
        f"range={range_count:,}, "
        f"missing={missing_count:,}, "
        f"zero={zero_count:,}"
    )


    if range_count != info["nonmissing"]:

        raise ValueError(
            f"{col}: valid range count differs."
        )


    if missing_count != info["missing"]:

        raise ValueError(
            f"{col}: missing count differs."
        )


    if zero_count != info["zero"]:

        raise ValueError(
            f"{col}: zero count differs."
        )


print(
    "PASS: Water variables validated."
)


# ============================================================
# 24. CONFIRM DECIMAL VARIABLES REMAIN FLOAT
# ============================================================

print(
    "\n--- DECIMAL DTYPE CHECK ---"
)


decimal_dtype_failures = []


for col in DECIMAL_COLUMNS:

    if not pd.api.types.is_float_dtype(
        df[col].dtype
    ):

        decimal_dtype_failures.append(
            col
        )


if decimal_dtype_failures:

    raise ValueError(
        "Some Dietary decimal variables "
        "are no longer floating point:\n"
        + str(
            decimal_dtype_failures
        )
    )


print(
    "PASS: All 50 Dietary decimal fields "
    "remain floating-point."
)


# ============================================================
# 25. FINAL VALIDATED ZERO PATTERN
# ============================================================

#
# Before correction:
#
#     ordinary zero count = 0
#
# Therefore every zero after correction must correspond
# exactly to one validated tiny-value location.
#

final_zero_counts = {}


for col in EXPECTED_COLUMNS:

    zero_count = int(
        df[col]
        .eq(0)
        .sum()
    )


    if zero_count > 0:

        final_zero_counts[col] = zero_count


print(
    "\n--- FINAL ZERO PATTERN ---"
)


print(
    "Variables containing zero:",
    len(final_zero_counts)
)


print(
    "Total zero values:",
    f"{sum(final_zero_counts.values()):,}"
)


if final_zero_counts != EXPECTED_TINY_COUNTS:

    raise ValueError(
        "Final zero pattern differs from "
        "validated source pattern."
    )


if sum(
    final_zero_counts.values()
) != 55066:

    raise ValueError(
        "Unexpected final zero total."
    )


print(
    "PASS: Final zero pattern exactly matches "
    "the 55,066 validated zero restorations."
)


# ============================================================
# 26. VALUE FIDELITY BEFORE EXPORT
# ============================================================

#
# ONLY tiny -> 0 restoration is allowed.
#
# All other values must remain EXACTLY numerically equal.
#

print(
    "\n--- VALUE FIDELITY BEFORE EXPORT ---"
)


pre_export_failures = []


for col in EXPECTED_COLUMNS:

    expected_values = (
        expected_df[col]
        .to_numpy(
            dtype=float
        )
    )


    current_values = (
        pd.to_numeric(
            df[col],
            errors="coerce"
        )
        .to_numpy(
            dtype=float,
            na_value=np.nan
        )
    )


    same = np.allclose(
        expected_values,
        current_values,
        rtol=0,
        atol=0,
        equal_nan=True
    )


    if not same:

        pre_export_failures.append(
            col
        )


if pre_export_failures:

    raise ValueError(
        "Unexpected numeric changes before export:\n"
        + str(
            pre_export_failures
        )
    )


print(
    "PASS: All 168 variables match "
    "the exact corrected XPT values."
)


# ============================================================
# 27. EXPORT CSV
# ============================================================

#
# CRITICAL DIETARY RULE:
#
# NO:
#
#     df.round(...)
#
# NO:
#
#     float_format=
#
# NO:
#
#     conversion of decimal fields to Int64
#

df.to_csv(
    csv_file,
    index=False,
    na_rep=""
)


print(
    "\nCSV created:"
)

print(
    csv_file
)


# ============================================================
# 28. RE-READ CSV WITH ROUND-TRIP FLOAT PARSER
# ============================================================

roundtrip_df = pd.read_csv(
    csv_file,
    low_memory=False,
    float_precision="round_trip"
)


if roundtrip_df.shape != df.shape:

    raise ValueError(
        "CSV dimensions changed."
    )


if (
    roundtrip_df.columns.tolist()
    != EXPECTED_COLUMNS
):

    raise ValueError(
        "CSV columns/order changed."
    )


print(
    "PASS: CSV structure preserved."
)


# ============================================================
# 29. EXACT CORRECTED XPT -> CSV NUMERIC FIDELITY
# ============================================================

print(
    "\n--- EXACT CORRECTED XPT -> CSV FIDELITY ---"
)


csv_fidelity_failures = []


for col in EXPECTED_COLUMNS:

    expected_values = (
        expected_df[col]
        .to_numpy(
            dtype=float
        )
    )


    exported_values = (
        pd.to_numeric(
            roundtrip_df[col],
            errors="coerce"
        )
        .to_numpy(
            dtype=float
        )
    )


    same = np.allclose(
        expected_values,
        exported_values,
        rtol=0,
        atol=0,
        equal_nan=True
    )


    if not same:

        csv_fidelity_failures.append(
            col
        )


if csv_fidelity_failures:

    raise ValueError(
        "Corrected XPT -> CSV differences:\n"
        + str(
            csv_fidelity_failures
        )
    )


print(
    "PASS: 0 numeric differences across "
    "all 168 variables."
)


# ============================================================
# 30. MISSING-VALUE FIDELITY
# ============================================================

missing_mismatches = 0


for col in EXPECTED_COLUMNS:

    expected_missing = (
        expected_df[col]
        .isna()
        .to_numpy()
    )


    exported_missing = (
        roundtrip_df[col]
        .isna()
        .to_numpy()
    )


    missing_mismatches += int(
        np.sum(
            expected_missing
            !=
            exported_missing
        )
    )


print(
    "\n--- MISSING-VALUE FIDELITY ---"
)


print(
    "Missing-position mismatches:",
    missing_mismatches
)


if missing_mismatches != 0:

    raise ValueError(
        "Missing-value positions changed."
    )


print(
    "PASS: Missing positions preserved exactly."
)


# ============================================================
# 31. READ FINAL CSV AS RAW TEXT
# ============================================================

raw_csv_df = pd.read_csv(
    csv_file,
    dtype=str,
    keep_default_na=False
)


# ============================================================
# 32. FINAL TINY-VALUE CHECK
# ============================================================

tiny_csv_count = 0


for col in EXPECTED_COLUMNS:

    values = pd.to_numeric(
        raw_csv_df[col]
        .where(
            raw_csv_df[col] != "",
            np.nan
        ),
        errors="coerce"
    )


    tiny_csv_count += int(
        values.eq(
            TINY_VALUE
        )
        .sum()
    )


print(
    "\n--- FINAL TINY VALUE CHECK ---"
)


print(
    "Tiny values remaining:",
    tiny_csv_count
)


if tiny_csv_count != 0:

    raise ValueError(
        "Tiny XPORT artifacts remain in CSV."
    )


print(
    "PASS: No tiny XPORT artifacts remain."
)


# ============================================================
# 33. .0 CHECK - INTEGER FIELDS ONLY
# ============================================================

#
# DO NOT globally check every field.
#
# The 50 genuine Dietary decimal fields are excluded.
#

print(
    "\n--- INTEGER FIELD .0 CHECK ---"
)


dot_zero_errors = {}


for col in INTEGER_COLUMNS:

    tokens = raw_csv_df[col]


    bad_mask = (
        tokens.ne("")
        &
        tokens.str.endswith(".0")
    )


    count = int(
        bad_mask.sum()
    )


    if count > 0:

        dot_zero_errors[col] = count


if dot_zero_errors:

    raise ValueError(
        "Unexpected '.0' formatting in "
        "integer/code fields:\n"
        + str(
            dot_zero_errors
        )
    )


print(
    "PASS: No unnecessary '.0' in "
    "the 118 integer/code fields."
)


# ============================================================
# 34. DECIMAL .0 VALUES ARE LEGITIMATE
# ============================================================

#
# INFORMATIONAL ONLY.
#
# Examples:
#
#     WTDRD1 = 0.0
#     WTDR2D = 0.0
#     DR1TALCO = 0.0
#     DR1_320Z = 0.0
#
# These are legitimate values in genuine decimal columns.
#

print(
    "\n--- LEGITIMATE DECIMAL .0 VALUES ---"
)


decimal_dot_zero_counts = {}


for col in DECIMAL_COLUMNS:

    count = int(
        (
            raw_csv_df[col]
            .ne("")
            &
            raw_csv_df[col]
            .str.endswith(".0")
        )
        .sum()
    )


    decimal_dot_zero_counts[col] = count


    print(
        f"{col}:",
        f"{count:,}"
    )


print(
    "PASS: Genuine decimal '.0' values "
    "are preserved and are not treated as errors."
)


# ============================================================
# 35. EXACT DIETARY DECIMAL FIDELITY
# ============================================================

#
# This is the most important Dietary fidelity test.
#
# rtol = 0
# atol = 0
#
# means no numerical change is accepted.
#

print(
    "\n--- EXACT DIETARY DECIMAL FIDELITY ---"
)


decimal_failures = []


for col in DECIMAL_COLUMNS:

    expected_values = (
        expected_df[col]
        .to_numpy(
            dtype=float
        )
    )


    exported_values = (
        roundtrip_df[col]
        .to_numpy(
            dtype=float
        )
    )


    same = np.allclose(
        expected_values,
        exported_values,
        rtol=0,
        atol=0,
        equal_nan=True
    )


    if not same:

        decimal_failures.append(
            col
        )


if decimal_failures:

    raise ValueError(
        "Dietary decimal fidelity failed:\n"
        + str(
            decimal_failures
        )
    )


print(
    "PASS: All 50 genuine Dietary decimal "
    "fields preserved exactly."
)


# ============================================================
# 36. SPECIFIC WTDRD1 CSV FIDELITY CHECK
# ============================================================

#
# Specifically verify that the value which caused the
# earlier validation error remains EXACTLY:
#
#     454277.717307
#
# after CSV export/re-read.
#

csv_wtdrd1_max = float(
    roundtrip_df.loc[
        roundtrip_df["WTDRD1"] > 0,
        "WTDRD1"
    ]
    .max()
)


print(
    "\n--- WTDRD1 CSV PRECISION CHECK ---"
)


print(
    "Final CSV numeric maximum:",
    repr(csv_wtdrd1_max)
)


if csv_wtdrd1_max != 454277.717307:

    raise ValueError(
        "WTDRD1 maximum changed during CSV export."
    )


print(
    "PASS: WTDRD1 maximum remains exactly "
    "454277.717307."
)


# ============================================================
# 37. FINAL CSV ZERO PATTERN
# ============================================================

csv_zero_counts = {}


for col in EXPECTED_COLUMNS:

    values = pd.to_numeric(
        raw_csv_df[col]
        .where(
            raw_csv_df[col] != "",
            np.nan
        ),
        errors="coerce"
    )


    zero_count = int(
        values.eq(0)
        .sum()
    )


    if zero_count > 0:

        csv_zero_counts[col] = zero_count


print(
    "\n--- FINAL CSV ZERO PATTERN ---"
)


print(
    "Variables containing zeros:",
    len(csv_zero_counts)
)


print(
    "Total zero values:",
    f"{sum(csv_zero_counts.values()):,}"
)


if csv_zero_counts != EXPECTED_TINY_COUNTS:

    raise ValueError(
        "Final CSV zero pattern differs from "
        "validated corrected source."
    )


print(
    "PASS: Final CSV contains exactly "
    "55,066 validated zero values."
)


# ============================================================
# 38. SCIENTIFIC NOTATION CHECK
# ============================================================

scientific_count = 0


for col in EXPECTED_COLUMNS:

    tokens = raw_csv_df[col]


    scientific_count += int(
        tokens.str.contains(
            r"[eE][+-]\d+",
            regex=True
        )
        .sum()
    )


print(
    "\n--- SCIENTIFIC NOTATION CHECK ---"
)


print(
    "Scientific notation occurrences:",
    scientific_count
)


if scientific_count != 0:

    raise ValueError(
        "Unexpected scientific notation found."
    )


print(
    "PASS: No scientific notation."
)


# ============================================================
# 39. FINAL SEQN CHECK
# ============================================================

final_seqn = pd.to_numeric(
    raw_csv_df["SEQN"],
    errors="raise"
)


if final_seqn.min() != 83732:

    raise ValueError(
        "Final minimum SEQN incorrect."
    )


if final_seqn.max() != 93702:

    raise ValueError(
        "Final maximum SEQN incorrect."
    )


if int(
    final_seqn
    .duplicated()
    .sum()
) != 0:

    raise ValueError(
        "Final CSV contains duplicate SEQN."
    )


if (
    raw_csv_df["SEQN"]
    .str.endswith(".0")
    .any()
):

    raise ValueError(
        "Final CSV SEQN still contains '.0'."
    )


print(
    "PASS: Final SEQN valid "
    "and contains no '.0'."
)


# ============================================================
# 40. FINAL SUMMARY
# ============================================================

print(
    "\n"
    + "=" * 100
)


print(
    "DR1TOT_I CONVERSION COMPLETE"
)


print(
    "=" * 100
)


print(
    "Cycle: 2015-2016"
)


print(
    "Component: Dietary - "
    "Total Nutrient Intakes, First Day"
)


print(
    "Rows:",
    f"{len(df):,}"
)


print(
    "Columns:",
    len(df.columns)
)


print(
    "SEQN range:",
    f"{df['SEQN'].min()}-{df['SEQN'].max()}"
)


print(
    "Original tiny artifacts:",
    f"{tiny_total:,}"
)


print(
    "Variables containing tiny artifacts:",
    tiny_variable_count
)


print(
    "Validated zero restorations:",
    f"{correction_total:,}"
)


print(
    "Genuine Dietary decimal fields:",
    len(DECIMAL_COLUMNS)
)


print(
    "Whole-number/code fields:",
    len(INTEGER_COLUMNS)
)


print(
    "WTDRD1 positive:",
    f"{wtdrd1_positive:,}"
)


print(
    "WTDRD1 zero:",
    f"{wtdrd1_zero:,}"
)


print(
    "WTDRD1 exact XPT minimum:",
    repr(actual_wtdrd1_min)
)


print(
    "WTDRD1 exact XPT maximum:",
    repr(actual_wtdrd1_max)
)


print(
    "CDC displayed WTDRD1 maximum:",
    "454277.71731"
)


print(
    "WTDR2D positive:",
    f"{wtdr2d_positive:,}"
)


print(
    "WTDR2D zero:",
    f"{wtdr2d_zero:,}"
)


print(
    "WTDR2D missing:",
    f"{wtdr2d_missing:,}"
)


print(
    "Reliable Day-1 dietary recalls:",
    int(
        df["DR1DRSTZ"]
        .eq(1)
        .sum()
    )
)


print(
    "Nutrient/component variables:",
    len(NUTRIENT_COLUMNS)
)


print(
    "XPT -> CSV unexpected numeric differences:",
    "0 expected"
)


print(
    "Missing-position differences:",
    "0 expected"
)


print(
    "Dietary decimal differences:",
    "0 expected"
)


print(
    "Tiny values remaining:",
    "0 expected"
)


print(
    "Unnecessary '.0' in integer fields:",
    "0 expected"
)


print(
    "Decimal '.0' values:",
    "ALLOWED / PRESERVED"
)


print(
    "Scientific notation:",
    "0 expected"
)


print(
    "\nFINAL RULE:"
)


print(
    "Dietary decimal values remain exactly AS IS."
)


print(
    "No Dietary decimal value was rounded."
)
# Out:
# ...
# NHANES 2015-2016 DR1TOT_I XPT -> CSV
# ...
# Rows: 9,544
# Columns: 168
# PASS: Structure = 9,544 rows x 168 columns.
#
# --- FIELD TYPE PLAN ---
# Genuine Dietary decimal fields: 50
# Whole-number/code fields: 118
#
# --- ORIGINAL XPT ZERO CHECK ---
# Ordinary numeric zeros before correction: 0
# Tiny XPORT artifacts: 55,066
# Variables containing tiny artifacts: 72
#
# Tiny values by variable:
# DR1TALCO    7226
# DR1TATOA    6950
# DR1TB12A    5641
# DR1BWATZ    4925
# DR1_330Z    4757
# DR1TTHEO    4525
# DR1TP184    3808
# DR1TCAFF    2283
# DR1TLYCO    2114
# DR1_320Z    1787
# WTDR2D      1479
# DR1TP226    1342
# DR1TM221    1147
# DR1TP205    1046
# DR1TACAR    1045
# WTDRD1      1038
# DR1TCRYP     770
# DR1TP225     732
# DR1DBIH      469
# DR1TS060     337
# DR1TS040     332
# DR1TFA       254
# DR1TVD       196
# DR1TS080     108
# DR1TCHOL     101
# DR1TBCAR      99
# DR1TLZ        84
# DR1TP204      72
# DR1TFF        71
# DR1TFIBE      70
# DR1TRET       47
# ...
