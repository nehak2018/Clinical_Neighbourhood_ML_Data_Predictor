# %%
# =================================================================================================
# PART 1 - Demographics part one will aggregate all data into 1 file
# Raw data : This is All Demographics data from NHANES
# Previously Done : To run this file, the list of CSVs below have processed datasets yearly into saperate notebooks
# Purpose : This Aggregator program combining all Demographics data 2004-2014 into one as below will get all yearly csvs and create one dataset file 2003-2014 
# Specification : Each NHANE dataset has SEQN "Participent ID" which is uniqud id for labs. 
# Files Used :  DEMO_C.csv, DEMO_D.csv, DEMO_E.csv,DEMO_F.csv, DEMO_G.csv, DEMO_H.csv
# Data Availability Matrix : https://docs.google.com/spreadsheets/d/1E_zIzHZsEs0o-XWx8HbTN7ZPODge7EEC/edit?gid=1721397761#gid=1721397761
# Source Site : https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public
# Developer Notes :  The notebook had created for windows desktop environment with Python3.
# File Creator : Neha Khairnar
# ===================================================================================================
# 📦 Step 1: Imports
# =========================
import pandas as pd
from pathlib import Path

# =========================
# 📂 Step 2: Define Paths
# =========================
BASE_DIR = Path().resolve().parent
DATA_DIR = BASE_DIR / "data" / "2007_2008" / "Demographics"

# List all demographic files (update names as per your files)
FILES = [
    "DEMO_E_corrected.csv",
    # "DEMO_D.csv",
    # "DEMO_E.csv",
    # "DEMO_F.csv",
    # "DEMO_G.csv",
    # "DEMO_H.csv"
]


# =========================
# 📥 Step 3: Load & Append
# =========================
dfs = []
for file in FILES:
    path = DATA_DIR / file
    #df = pd.read_csv(path)  
    
    df = pd.read_csv(
        path,
        dtype=str,
        keep_default_na=False
    )

    # Standardize column names
    df.columns = df.columns.str.upper()
    # Optional: Add survey cycle column
    if file == "DEMO_E_corrected.csv":
        df["CYCLE"] = "2007-2008"
        df["Source"] = "DEMO_E"
    print(file, "shape:", df.shape)
    dfs.append(df)


# =========================
# 🔗 Step 4: Concatenate (Append)
# =========================
demo_all = pd.concat(dfs, axis=0, ignore_index=True)

# =========================
# 👀 Step 5: Preview
# =========================
print("Combined Demographics Preview:")
display(demo_all.head(10))

# =========================
# 📊 Step 6: Validation
# =========================
print("Final shape:", demo_all.shape)

# Check duplicate SEQN (should be unique across cycles)
duplicates = demo_all["SEQN"].duplicated().sum()
print("Duplicate SEQN:", duplicates)

# =========================
# 🧼 Step 7: Optional Cleaning
# =========================
# Drop exact duplicates if any
demo_all = demo_all.drop_duplicates()

# =========================
# 💾 Step 8: Save Output
# =========================
OUTPUT_DIR = BASE_DIR / "data" / "processed_v3/2007_2008"
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)

demo_all.to_csv(OUTPUT_DIR / "neighbourhood_nhanes_demographics_2007_2008_raw_corrected.csv", index=False)

print("Saved to:")
print(OUTPUT_DIR / "neighbourhood_nhanes_demographics_2007_2008_raw_corrected.csv")
# Out:
# DEMO_E_corrected.csv shape: (10149, 45)
# Combined Demographics Preview:
#     SEQN SDDSRVYR RIDSTATR RIDEXMON RIAGENDR RIDAGEYR RIDAGEMN RIDAGEEX  \
# 0  41475        5        2        2        2       62      751      752
# 1  41476        5        2        1        2        6       81       82
# 2  41477        5        2        2        1       71      859      860
# 3  41478        5        2        2        2        1       17       17
# 4  41479        5        2        1        1       52      629      630
# 5  41480        5        2        1        1        6       81       81
# 6  41481        5        2        1        1       21      254      254
# 7  41482        5        2        2        1       64      778      779
# 8  41483        5        2        1        1       66      803      804
# 9  41484        5        2        1        1        0        9       10
#
#   RIDRETH1 DMQMILIT  ... MIALANG MIAPROXY MIAINTRP AIALANG      WTINT2YR  \
# 0        5        2  ...       1        2        2       1  59356.356426
# 1        5           ...                                    35057.218405
# 2        3        1  ...       1        2        2       1   9935.266183
# 3        3           ...                                    12846.712058
# 4        1        2  ...       2        2        2       2   8727.797555
# 5        1           ...                                     7379.745086
# 6        4        2  ...       1        2        2       1  24342.505253
# 7        1        2  ...       2        2        2       2   9811.075078
# 8        4        1  ...       1        2        2       1   8058.685296
# 9        3           ...                                     8942.951928
#
#        WTMEC2YR SDMVPSU SDMVSTRA      CYCLE  Source
# 0  60045.772497       1       60  2007-2008  DEMO_E
# 1   35353.21044       1       70  2007-2008  DEMO_E
# 2  10074.150074       1       67  2007-2008  DEMO_E
# 3  14560.472652       2       59  2007-2008  DEMO_E
# 4   9234.055759       1       70  2007-2008  DEMO_E
# 5   7297.067503       2       69  2007-2008  DEMO_E
# 6  24655.376656       2       68  2007-2008  DEMO_E
# 7  11602.178638       2       65  2007-2008  DEMO_E
# 8   7920.812275       2       66  2007-2008  DEMO_E
# 9   9259.270099       2       59  2007-2008  DEMO_E
#
# [10 rows x 45 columns]
# Final shape: (10149, 45)
# Duplicate SEQN: 0
# Saved to:
# C:\Users\User\Desktop\Projects\Clinical_Neighbourhood_ML_Data_Predictor\Clinical_Neighbourhood_ML_Data_Predictor\data\processed_v3\2007_2008\neighbourhood_nhanes_demographics_2007_2008_raw_corrected.csv
