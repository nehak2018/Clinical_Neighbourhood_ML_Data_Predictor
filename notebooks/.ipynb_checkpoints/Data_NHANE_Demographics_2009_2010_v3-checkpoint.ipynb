# %%
# =================================================================================================
# PART 1 - Demographics part one will aggregate all data into 1 file
# Raw data : This is All Demographics data from NHANES
# Previously Done : To run this file, the list of CSVs below have processed datasets yearly into saperate notebooks
# Purpose : This Aggregator program combining all Demographics data 2004-2014 into one as below will get all yearly csvs and create one dataset file 2003-2014 
# Specification : Each NHANE dataset has SEQN "Participent ID" which is uniqud id for labs. 
# Files Used :  DEMO_C.csv, DEMO_D.csv, DEMO_E.csv,DEMO_F.csv, DEMO_G.csv, DEMO_H.csv
# Data Availability Matrix : https://docs.google.com/spreadsheets/d/1E_zIzHZsEs0o-XWx8HbTN7ZPODge7EEC/edit?gid=1721397761#gid=1721397761
# Source Site : https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public
# Developer Notes :  The notebook had created for windows desktop environment with Python3.
# File Creator : Neha Khairnar
# ===================================================================================================
# 📦 Step 1: Imports
# =========================
import pandas as pd
from pathlib import Path

# =========================
# 📂 Step 2: Define Paths
# =========================
BASE_DIR = Path().resolve().parent
DATA_DIR = BASE_DIR / "data" / "2009_2010" / "Demographics"

# List all demographic files (update names as per your files)
FILES = [
    "DEMO_F_corrected.csv",
    # "DEMO_D.csv",
    # "DEMO_E.csv",
    # "DEMO_F.csv",
    # "DEMO_G.csv",
    # "DEMO_H.csv"
]


# =========================
# 📥 Step 3: Load & Append
# =========================
dfs = []
for file in FILES:
    path = DATA_DIR / file
    #df = pd.read_csv(path)  
    
    df = pd.read_csv(
        path,
        dtype=str,
        keep_default_na=False
    )

    # Standardize column names
    df.columns = df.columns.str.upper()
    # Optional: Add survey cycle column
    if file == "DEMO_F_corrected.csv":
        df["CYCLE"] = "2009-2010"
        df["Source"] = "DEMO_F"
    print(file, "shape:", df.shape)
    dfs.append(df)


# =========================
# 🔗 Step 4: Concatenate (Append)
# =========================
demo_all = pd.concat(dfs, axis=0, ignore_index=True)

# =========================
# 👀 Step 5: Preview
# =========================
print("Combined Demographics Preview:")
display(demo_all.head(10))

# =========================
# 📊 Step 6: Validation
# =========================
print("Final shape:", demo_all.shape)

# Check duplicate SEQN (should be unique across cycles)
duplicates = demo_all["SEQN"].duplicated().sum()
print("Duplicate SEQN:", duplicates)

# =========================
# 🧼 Step 7: Optional Cleaning
# =========================
# Drop exact duplicates if any
demo_all = demo_all.drop_duplicates()

# =========================
# 💾 Step 8: Save Output
# =========================
OUTPUT_DIR = BASE_DIR / "data" / "processed_v3/2009_2010"
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)

demo_all.to_csv(OUTPUT_DIR / "neighbourhood_nhanes_demographics_2009_2010_raw_corrected.csv", index=False)

print("Saved to:")
print(OUTPUT_DIR / "neighbourhood_nhanes_demographics_2009_2010_raw_corrected.csv")
# Out:
# DEMO_F_corrected.csv shape: (10537, 45)
# Combined Demographics Preview:
#     SEQN SDDSRVYR RIDSTATR RIDEXMON RIAGENDR RIDAGEYR RIDAGEMN RIDAGEEX  \
# 0  51624        6        2        1        1       34      409      410
# 1  51625        6        2        2        1        4       49       50
# 2  51626        6        2        1        1       16      202      202
# 3  51627        6        2        1        1       10      131      132
# 4  51628        6        2        2        2       60      722      722
# 5  51629        6        2        1        1       26      313      313
# 6  51630        6        2        1        2       49      596      596
# 7  51631        6        2        1        2        1       12       12
# 8  51632        6        2        1        1       10      124      126
# 9  51633        6        2        2        1       80
#
#   RIDRETH1 DMQMILIT  ... MIALANG MIAPROXY MIAINTRP AIALANG      WTINT2YR  \
# 0        3        2  ...       1        2        2       1  80100.543512
# 1        5           ...                                    53901.104285
# 2        4           ...       1        2        2       1  13953.078343
# 3        4           ...       1        2        2          11664.899398
# 4        4        2  ...       1        2        2       1  20090.339256
# 5        1        2  ...       1        2        2       1  22537.826997
# 6        3        2  ...       1        2        2       1  74212.269993
# 7        3           ...                                    23306.397744
# 8        2           ...       1        2        2           8056.943427
# 9        3        2  ...       1        2        2          11998.401196
#
#        WTMEC2YR SDMVPSU SDMVSTRA      CYCLE  Source
# 0  81528.772006       1       83  2009-2010  DEMO_F
# 1  56995.035425       2       79  2009-2010  DEMO_F
# 2   14509.27886       1       84  2009-2010  DEMO_F
# 3  12041.635365       2       86  2009-2010  DEMO_F
# 4  21000.338724       2       75  2009-2010  DEMO_F
# 5  22633.581873       1       88  2009-2010  DEMO_F
# 6  74112.486841       2       85  2009-2010  DEMO_F
# 7  24776.491957       2       86  2009-2010  DEMO_F
# 8   8175.945593       2       88  2009-2010  DEMO_F
# 9  12381.115324       1       77  2009-2010  DEMO_F
#
# [10 rows x 45 columns]
# Final shape: (10537, 45)
# Duplicate SEQN: 0
# Saved to:
# C:\Users\User\Desktop\Projects\Clinical_Neighbourhood_ML_Data_Predictor\Clinical_Neighbourhood_ML_Data_Predictor\data\processed_v3\2009_2010\neighbourhood_nhanes_demographics_2009_2010_raw_corrected.csv
