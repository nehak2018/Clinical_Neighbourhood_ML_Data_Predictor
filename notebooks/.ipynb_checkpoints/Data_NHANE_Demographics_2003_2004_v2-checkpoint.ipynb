# %%
# =================================================================================================
# PART 1 - Demographics part one will aggregate all data into 1 file
# Raw data : This is All Demographics data from NHANES
# Previously Done : To run this file, the list of CSVs below have processed datasets yearly into saperate notebooks
# Purpose : This Aggregator program combining all Demographics data 2004-2014 into one as below will get all yearly csvs and create one dataset file 2003-2014 
# Specification : Each NHANE dataset has SEQN "Participent ID" which is uniqud id for labs. 
# Files Used :  DEMO_C.csv, DEMO_D.csv, DEMO_E.csv,DEMO_F.csv, DEMO_G.csv, DEMO_H.csv
# Data Availability Matrix : https://docs.google.com/spreadsheets/d/1E_zIzHZsEs0o-XWx8HbTN7ZPODge7EEC/edit?gid=1721397761#gid=1721397761
# Source Site : https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public
# Developer Notes :  The notebook had created for windows desktop environment with Python3.
# File Creator : Neha Khairnar
# ===================================================================================================
# 📦 Step 1: Imports
# =========================
import pandas as pd
from pathlib import Path

# =========================
# 📂 Step 2: Define Paths
# =========================
BASE_DIR = Path().resolve().parent
DATA_DIR = BASE_DIR / "data" / "2003_2004" / "Demographics"

# List all demographic files (update names as per your files)
FILES = [
    "DEMO_C.csv",
    # "DEMO_D.csv",
    # "DEMO_E.csv",
    # "DEMO_F.csv",
    # "DEMO_G.csv",
    # "DEMO_H.csv"
]


# =========================
# 📥 Step 3: Load & Append
# =========================
dfs = []

for file in FILES:
    path = DATA_DIR / file
    df = pd.read_csv(path)
    
    # Standardize column names
    df.columns = df.columns.str.upper()
    
    # Optional: Add survey cycle column
    df["CYCLE"] = file.replace(".csv", "")
    
    print(file, "shape:", df.shape)
    
    dfs.append(df)


# =========================
# 🔗 Step 4: Concatenate (Append)
# =========================
demo_all = pd.concat(dfs, axis=0, ignore_index=True)


# =========================
# 👀 Step 5: Preview
# =========================
print("Combined Demographics Preview:")
display(demo_all.head(10))


# =========================
# 📊 Step 6: Validation
# =========================
print("Final shape:", demo_all.shape)

# Check duplicate SEQN (should be unique across cycles)
duplicates = demo_all["SEQN"].duplicated().sum()
print("Duplicate SEQN:", duplicates)


# =========================
# 🧼 Step 7: Optional Cleaning
# =========================
# Drop exact duplicates if any
demo_all = demo_all.drop_duplicates()


# =========================
# 💾 Step 8: Save Output
# =========================
OUTPUT_DIR = BASE_DIR / "data" / "processed_v2"
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)

demo_all.to_csv(OUTPUT_DIR / "neighbourhood_nhanes_demographics_2003_2014_raw.csv", index=False)

print("Saved to:")
print(OUTPUT_DIR / "neighbourhood_nhanes_demographics_2003_2014_appended.csv")
# Out:
# DEMO_C.csv shape: (10122, 45)
# Combined Demographics Preview:
#       SEQN  SDDSRVYR  RIDSTATR  RIDEXMON  RIAGENDR      RIDAGEYR  RIDAGEMN  \
# 0  21005.0       3.0       2.0       1.0       1.0  1.900000e+01     232.0
# 1  21006.0       3.0       2.0       2.0       2.0  1.600000e+01     203.0
# 2  21007.0       3.0       2.0       1.0       2.0  1.400000e+01     172.0
# 3  21008.0       3.0       2.0       2.0       1.0  1.700000e+01     208.0
# 4  21009.0       3.0       2.0       2.0       1.0  5.500000e+01     671.0
# 5  21010.0       3.0       2.0       2.0       2.0  5.200000e+01     633.0
# 6  21011.0       3.0       2.0       1.0       1.0  5.397605e-79       3.0
# 7  21012.0       3.0       2.0       2.0       1.0  6.300000e+01     765.0
# 8  21013.0       3.0       2.0       1.0       2.0  1.300000e+01     163.0
# 9  21014.0       3.0       2.0       2.0       1.0  3.000000e+00      42.0
#
#    RIDAGEEX  RIDRETH1  RIDRETH2  ...  FIAINTRP  MIALANG  MIAPROXY  MIAINTRP  \
# 0     233.0       4.0       2.0  ...       2.0      1.0       2.0       2.0
# 1     205.0       4.0       2.0  ...       2.0      1.0       2.0       2.0
# 2     172.0       3.0       1.0  ...       2.0      1.0       2.0       2.0
# 3     209.0       4.0       2.0  ...       2.0      1.0       2.0       2.0
# 4     672.0       3.0       1.0  ...       2.0      1.0       2.0       2.0
# 5     634.0       3.0       1.0  ...       2.0      1.0       2.0       2.0
# 6       4.0       1.0       3.0  ...       2.0      NaN       NaN       NaN
# 7     766.0       4.0       2.0  ...       2.0      NaN       NaN       NaN
# 8     164.0       4.0       2.0  ...       2.0      1.0       2.0       2.0
# 9      42.0       4.0       2.0  ...       2.0      NaN       NaN       NaN
#
#    AIALANG      WTINT2YR      WTMEC2YR  SDMVPSU  SDMVSTRA   CYCLE
# 0      1.0   5512.320949   5824.782465      2.0      39.0  DEMO_C
# 1      1.0   5422.140453   5564.039715      1.0      41.0  DEMO_C
# 2      1.0  39764.177412  40591.066325      2.0      35.0  DEMO_C
# 3      1.0   5599.499351   5696.750596      1.0      32.0  DEMO_C
# 4      1.0  97593.678977  97731.727244      2.0      31.0  DEMO_C
# 5      1.0  39599.362689  43286.576474      1.0      29.0  DEMO_C
# 6      NaN   1647.617690   1692.168138      2.0      40.0  DEMO_C
# 7      NaN  12629.440480  12947.338142      2.0      33.0  DEMO_C
# 8      1.0   7174.371037   7304.945503      1.0      37.0  DEMO_C
# 9      NaN   7498.031463   8385.245979      1.0      33.0  DEMO_C
#
# [10 rows x 45 columns]
# Final shape: (10122, 45)
# Duplicate SEQN: 0
# Saved to:
# C:\Users\User\Desktop\Projects\Clinical_Neighbourhood_ML_Data_Predictor\Clinical_Neighbourhood_ML_Data_Predictor\data\processed_v2\neighbourhood_nhanes_demographics_2003_2014_appended.csv
