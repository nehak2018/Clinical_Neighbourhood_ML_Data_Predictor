# %%
# =================================================================================================
# Raw data : This is Questionnaire data from NHANES 2003-2004
# Purpose : Creating unified raw CSV file from NHANES questionnaire CSV files.
# Specification : Each NHANES dataset has SEQN "Participant ID", which is the unique respondent ID.
# Files Used : ALQ_C.csv, BPQ_C.csv, DIQ_C.csv, HIQ_C.csv, HUQ_C.csv, SMQ_C.csv, SMQFAM_C.csv, WHQ_C.csv
# Data Dictionary : CDC NHANES 2003-2004 Questionnaire Data Dictionary
# Data Availability Matrix : Created in this notebook using SEQN presence flags
# Source Site : https://wwwn.cdc.gov/nchs/nhanes/search/datapage.aspx?Component=Questionnaire&CycleBeginYear=2003
# Developer Notes : The notebook was created for Windows desktop environment with Python3.
# File Creator : Neha Khairnar
# =================================================================================================

# 📦 Step 1: Imports
import pandas as pd
from pathlib import Path

# =================================================================================================
# 📂 Step 2: Paths below resolved for locally run datasets
# =================================================================================================

BASE_DIR = Path().resolve().parent

DATA_DIR = BASE_DIR / "data" / "Datasets" / "NHANE_Continuous_DemographicsData_2011_2012_Questionnaire"

alcohol_file = DATA_DIR / "ALQ_G.csv"
bp_chol_file = DATA_DIR / "BPQ_G.csv"
diabetes_file = DATA_DIR / "DIQ_G.csv"
insurance_file = DATA_DIR / "HIQ_G.csv"
access_file = DATA_DIR / "HUQ_G.csv"
smoking_file = DATA_DIR / "SMQ_G.csv"
household_smokers_file = DATA_DIR / "SMQFAM_G.csv"
weight_history_file = DATA_DIR / "WHQ_G.csv"

files = {
    "alcohol_ALQ_C": alcohol_file,
    "blood_pressure_cholesterol_BPQ_C": bp_chol_file,
    "diabetes_DIQ_C": diabetes_file,
    "health_insurance_HIQ_C": insurance_file,
    "hospital_access_HUQ_C": access_file,
    "smoking_SMQ_C": smoking_file,
    "household_smokers_SMQFAM_C": household_smokers_file,
    "weight_history_WHQ_C": weight_history_file
}

# =================================================================================================
# 📥 Step 3: Load ALL Files
# =================================================================================================

dfs = {}

for name, path in files.items():
    df_temp = pd.read_csv(path)
    df_temp.columns = df_temp.columns.str.upper()
    
    # SEQN presence flag for troubleshooting
    df_temp[f"SEQN_in_{name}"] = df_temp["SEQN"].notna()
    
    dfs[name] = df_temp

# =================================================================================================
# 📊 Step 4: File Structure Summary
# =================================================================================================

summary = []

for name, df_temp in dfs.items():
    summary.append({
        "file": name,
        "rows": df_temp.shape[0],
        "columns": df_temp.shape[1],
        "column_names": list(df_temp.columns)
    })

summary_df = pd.DataFrame(summary)

print("📊 NHANES Questionnaire File Structure Summary:\n")
display(summary_df[["file", "rows", "columns", "column_names"]])

for i, row in summary_df.iterrows():
    print("\n" + "="*80)
    print("FILE:", row["file"])
    print("COLUMNS:", len(row["column_names"]))
    print(row["column_names"])

# =================================================================================================
# 🔗 Step 5: Merge ALL columns using FULL OUTER JOIN on SEQN
# =================================================================================================

df = dfs["alcohol_ALQ_C"]

for name in [
    "blood_pressure_cholesterol_BPQ_C",
    "diabetes_DIQ_C",
    "health_insurance_HIQ_C",
    "hospital_access_HUQ_C",
    "smoking_SMQ_C",
    "household_smokers_SMQFAM_C",
    "weight_history_WHQ_C"
]:
    df = df.merge(
        dfs[name],
        on="SEQN",
        how="outer",
        suffixes=("", f"_{name}")
    )

# =================================================================================================
# 🧠 Step 6: SEQN Presence Flags
# =================================================================================================

for name in files.keys():
    flag_col = f"SEQN_in_{name}"
    present_col = f"present_{name}"
    
    if flag_col in df.columns:
        df[present_col] = df[flag_col].fillna(False)

display(df.head(20))

print("Unique SEQN count:", df["SEQN"].nunique())
print("Final shape:", df.shape)

# =================================================================================================
# 🧠 Step 7: Rename Columns for Readability
# Naming convention: OriginalVariable_description
# =================================================================================================

rename_map_questionnaire = {
    # ID
    "SEQN": "SEQN",

    # Alcohol Use - ALQ_C
    "ALQ101": "ALQ101_had_at_least_12_alcohol_drinks_lifetime",
    "ALQ110": "ALQ110_had_at_least_12_alcohol_drinks_past_year",
    "ALQ120Q": "ALQ120Q_days_drank_alcohol_past_12_months_quantity",
    "ALQ120U": "ALQ120U_days_drank_alcohol_past_12_months_unit",
    "ALQ130": "ALQ130_average_drinks_per_drinking_day",
    "ALQ140Q": "ALQ140Q_days_had_5_or_more_drinks_quantity",
    "ALQ140U": "ALQ140U_days_had_5_or_more_drinks_unit",

    # Blood Pressure & Cholesterol - BPQ_C
    "BPQ020": "BPQ020_ever_told_high_blood_pressure",
    "BPQ030": "BPQ030_told_high_blood_pressure_2_or_more_times",
    "BPQ040A": "BPQ040A_taking_prescription_for_hypertension",
    "BPQ050A": "BPQ050A_now_taking_prescribed_hypertension_medicine",
    "BPQ060": "BPQ060_ever_had_blood_cholesterol_checked",
    "BPQ070": "BPQ070_when_cholesterol_checked",
    "BPQ080": "BPQ080_ever_told_high_cholesterol",
    "BPQ090D": "BPQ090D_told_to_take_prescription_for_cholesterol",

    # Diabetes - DIQ_C
    "DIQ010": "DIQ010_ever_told_diabetes",
    "DID040": "DID040_age_when_first_told_diabetes",
    "DIQ050": "DIQ050_now_taking_insulin",
    "DID060": "DID060_how_long_taking_insulin",
    "DIQ060U": "DIQ060U_insulin_duration_unit",
    "DIQ070": "DIQ070_take_diabetic_pills",
    "DIQ170": "DIQ170_ever_told_pre_diabetes",
    "DIQ172": "DIQ172_ever_told_health_risk_for_diabetes",

    # Health Insurance - HIQ_C
    "HIQ011": "HIQ011_covered_by_health_insurance",
    "HIQ031A": "HIQ031A_private_insurance",
    "HIQ031B": "HIQ031B_medicare",
    "HIQ031C": "HIQ031C_medi_gap",
    "HIQ031D": "HIQ031D_medicaid",
    "HIQ031E": "HIQ031E_schip",
    "HIQ031F": "HIQ031F_military_health_care",
    "HIQ031G": "HIQ031G_indian_health_service",
    "HIQ031H": "HIQ031H_state_sponsored_plan",
    "HIQ031I": "HIQ031I_other_government_insurance",
    "HIQ031J": "HIQ031J_single_service_plan",
    "HIQ031AA": "HIQ031AA_no_insurance_type",
    "HIQ260": "HIQ260_gap_in_health_insurance_past_year",

    # Hospital Utilization & Access to Care - HUQ_C
    "HUQ010": "HUQ010_general_health_condition",
    "HUQ030": "HUQ030_routine_place_to_go_for_healthcare",
    "HUQ040": "HUQ040_type_place_most_often_go_for_healthcare",
    "HUQ050": "HUQ050_times_received_healthcare_past_year",
    "HUQ060": "HUQ060_overnight_hospital_patient_past_year",
    "HUQ070": "HUQ070_time_since_last_healthcare_visit",

    # Smoking Adult - SMQ_C
    "SMQ020": "SMQ020_smoked_at_least_100_cigarettes_lifetime",
    "SMD030": "SMD030_age_started_smoking_regularly",
    "SMQ040": "SMQ040_now_smoke_cigarettes",
    "SMQ050Q": "SMQ050Q_time_since_quit_smoking_quantity",
    "SMQ050U": "SMQ050U_time_since_quit_smoking_unit",
    "SMD070": "SMD070_cigarettes_smoked_per_day_when_smoked",
    "SMD075": "SMD075_cigarettes_smoked_per_day_now",

    # Household Smokers - SMQFAM_C
    "SMAQUEX": "SMAQUEX_smoking_family_questionnaire_status",
    "SMD410": "SMD410_number_of_smokers_in_home",
    "SMD415": "SMD415_number_of_people_who_smoke_inside_home",

    # Weight History - WHQ_C
    "WHD010": "WHD010_current_self_reported_height_inches",
    "WHD020": "WHD020_current_self_reported_weight_pounds",
    "WHQ030": "WHQ030_how_do_you_consider_your_weight",
    "WHQ040": "WHQ040_like_to_weigh_more_less_same",
    "WHD050": "WHD050_self_reported_weight_1_year_ago_pounds",
    "WHQ060": "WHQ060_weight_change_intentional",
    "WHQ070": "WHQ070_tried_to_lose_weight_past_year",
    "WHD080A": "WHD080A_weight_loss_method_ate_less_food",
    "WHD080B": "WHD080B_weight_loss_method_switched_foods",
    "WHD080C": "WHD080C_weight_loss_method_exercise",
    "WHD110": "WHD110_self_reported_weight_10_years_ago_pounds"
}

df = df.rename(columns={k: v for k, v in rename_map_questionnaire.items() if k in df.columns})

# =================================================================================================
# 👀 Step 8: Validate Final Result
# =================================================================================================

print("📋 Final Columns After Merge + Rename:")
print(df.columns.tolist())

print("\n📊 Final Shape:", df.shape)
print("Unique SEQN count:", df["SEQN"].nunique())

display(df.head(20))

# =================================================================================================
# 📊 Step 9: Data Availability Matrix
# =================================================================================================

availability_cols = [col for col in df.columns if col.startswith("present_")]

availability_matrix = df[["SEQN"] + availability_cols].copy()

print("📊 Data Availability Matrix:")
display(availability_matrix.head(20))

availability_summary = []

for col in availability_cols:
    availability_summary.append({
        "dataset": col.replace("present_", ""),
        "available_records": df[col].sum(),
        "missing_records": df.shape[0] - df[col].sum(),
        "availability_percent": round((df[col].sum() / df.shape[0]) * 100, 2)
    })

availability_summary_df = pd.DataFrame(availability_summary)

display(availability_summary_df)

# =================================================================================================
# 💾 Step 10: Save Final Output
# =================================================================================================

OUTPUT_DIR = BASE_DIR / "data" / "processed"/ "NHANE_Questionnair"
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)

OUTPUT_PATH = OUTPUT_DIR / "neighbourhood_nhanes_questionnaire_2011_2012.csv"

df.to_csv(OUTPUT_PATH, index=False)

print("\n✅ Saved to:")
print(OUTPUT_PATH)
# Out:
# 📊 NHANES Questionnaire File Structure Summary:
#                                file   rows  columns  \
# 0                     alcohol_ALQ_C   6059       10
# 1  blood_pressure_cholesterol_BPQ_C   6889       22
# 2                    diabetes_DIQ_C  10109       21
# 3            health_insurance_HIQ_C  10537       17
# 4             hospital_access_HUQ_C  10537       11
# 5                     smoking_SMQ_C   7528       38
# 6        household_smokers_SMQFAM_C  10537        6
# 7              weight_history_WHQ_C   6889       64
#
#                                         column_names
# 0  [SEQN, ALQ101, ALQ110, ALQ120Q, ALQ120U, ALQ13...
# 1  [SEQN, BPQ020, BPQ030, BPD035, BPQ040A, BPQ050...
# 2  [SEQN, DIQ010, DID040, DIQ160, DIQ170, DIQ180,...
# 3  [SEQN, HIQ011, HIQ031A, HIQ031B, HIQ031C, HIQ0...
# 4  [SEQN, HUQ010, HUQ020, HUQ030, HUQ040, HUQ050,...
# 5  [SEQN, SMQ020, SMD030, SMQ040, SMQ050Q, SMQ050...
# 6  [SEQN, SMD410, SMD415, SMD415A, SMD430, SEQN_i...
# 7  [SEQN, WHD010, WHD020, WHQ030, WHQ040, WHD045,...
# ================================================================================
# FILE: alcohol_ALQ_C
# COLUMNS: 10
# ['SEQN', 'ALQ101', 'ALQ110', 'ALQ120Q', 'ALQ120U', 'ALQ130', 'ALQ140Q', 'ALQ140U', 'ALQ150', 'SEQN_in_alcohol_ALQ_C']
#
# ================================================================================
# FILE: blood_pressure_cholesterol_BPQ_C
# COLUMNS: 22
# ['SEQN', 'BPQ020', 'BPQ030', 'BPD035', 'BPQ040A', 'BPQ050A', 'BPQ057', 'BPQ056', 'BPD058', 'BPQ059', 'BPQ060', 'BPQ070', 'BPQ080', 'BPQ090A', 'BPQ090B', 'BPQ090C', 'BPQ090D', 'BPQ100A', 'BPQ100B', 'BPQ100C', 'BPQ100D', 'SEQN_in_blood_pressure_cholesterol_BPQ_C']
#
# ================================================================================
# FILE: diabetes_DIQ_C
# COLUMNS: 21
# ['SEQN', 'DIQ010', 'DID040', 'DIQ160', 'DIQ170', 'DIQ180', 'DIQ050', 'DID060', 'DIQ060U', 'DIQ070', 'DIQ230', 'DIQ240', 'DID250', 'DID260', 'DIQ260U', 'DID341', 'DID350', 'DIQ350U', 'DIQ360', 'DIQ080', 'SEQN_in_diabetes_DIQ_C']
#
# ================================================================================
# FILE: health_insurance_HIQ_C
# COLUMNS: 17
# ['SEQN', 'HIQ011', 'HIQ031A', 'HIQ031B', 'HIQ031C', 'HIQ031D', 'HIQ031E', 'HIQ031F', 'HIQ031H', 'HIQ031I', 'HIQ031J', 'HIQ031AA', 'HIQ260', 'HIQ105', 'HIQ270', 'HIQ210', 'SEQN_in_health_insurance_HIQ_C']
#
# ================================================================================
# FILE: hospital_access_HUQ_C
# COLUMNS: 11
# ['SEQN', 'HUQ010', 'HUQ020', 'HUQ030', 'HUQ040', 'HUQ050', 'HUQ060', 'HUQ071', 'HUD080', 'HUQ090', 'SEQN_in_hospital_access_HUQ_C']
#
# ================================================================================
# FILE: smoking_SMQ_C
# COLUMNS: 38
# ['SEQN', 'SMQ020', 'SMD030', 'SMQ040', 'SMQ050Q', 'SMQ050U', 'SMD055', 'SMD057', 'SMQ077', 'SMD641', 'SMD650', 'SMD093', 'SMDUPCA', 'SMD100BR', 'SMD100FL', 'SMD100MN', 'SMD100LN', 'SMD100TR', 'SMD100NI', 'SMD100CO', 'SMQ620', 'SMD630', 'SMQ660', 'SMQ664M', 'SMQ664C', 'SMQ664W', 'SMQ664B', 'SMQ664O', 'SMQ666M', 'SMQ666C', 'SMQ666K', 'SMQ666W', 'SMQ666B', 'SMQ666S', 'SMQ666O', 'SMQ670', 'SMAQUEX2', 'SEQN_in_smoking_SMQ_C']
#
# ================================================================================
# FILE: household_smokers_SMQFAM_C
# COLUMNS: 6
# ['SEQN', 'SMD410', 'SMD415', 'SMD415A', 'SMD430', 'SEQN_in_household_smokers_SMQFAM_C']
#
# ================================================================================
# FILE: weight_history_WHQ_C
# COLUMNS: 64
# ['SEQN', 'WHD010', 'WHD020', 'WHQ030', 'WHQ040', 'WHD045', 'WHD050', 'WHQ060', 'WHQ070', 'WHD080A', 'WHD080B', 'WHD080C', 'WHD080D', 'WHD080E', 'WHD080F', 'WHD080G', 'WHD080H', 'WHD080I', 'WHD080J', 'WHD080K', 'WHD080L', 'WHD080M', 'WHD080N', 'WHD080O', 'WHD080P', 'WHD080Q', 'WHD080R', 'WHD080S', 'WHD080T', 'WHQ270', 'WHQ280A', 'WHQ280B', 'WHQ280C', 'WHQ280D', 'WHQ280E', 'WHQ090', 'WHD100A', 'WHD100B', 'WHD100C', 'WHD100D', 'WHD100E', 'WHD100F', 'WHD100G', 'WHD100H', 'WHD100I', 'WHD100J', 'WHD100K', 'WHD100L', 'WHD100M', 'WHD100N', 'WHD100O', 'WHD100P', 'WHD100Q', 'WHD100R', 'WHD100S', 'WHD100T', 'WHQ210', 'WHD220', 'WHD110', 'WHD120', 'WHD130', 'WHD140', 'WHQ150', 'SEQN_in_weight_history_WHQ_C']
# C:\Users\NVK00\AppData\Local\Temp\ipykernel_19672\3941891329.py:116: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[present_col] = df[flag_col].fillna(False)
# C:\Users\NVK00\AppData\Local\Temp\ipykernel_19672\3941891329.py:116: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[present_col] = df[flag_col].fillna(False)
# C:\Users\NVK00\AppData\Local\Temp\ipykernel_19672\3941891329.py:116: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[present_col] = df[flag_col].fillna(False)
# C:\Users\NVK00\AppData\Local\Temp\ipykernel_19672\3941891329.py:116: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[present_col] = df[flag_col].fillna(False)
# C:\Users\NVK00\AppData\Local\Temp\ipykernel_19672\3941891329.py:116: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[present_col] = df[flag_col].fillna(False)
# C:\Users\NVK00\AppData\Local\Temp\ipykernel_19672\3941891329.py:116: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[present_col] = df[flag_col].fillna(False)
# C:\Users\NVK00\AppData\Local\Temp\ipykernel_19672\3941891329.py:116: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[present_col] = df[flag_col].fillna(False)
# C:\Users\NVK00\AppData\Local\Temp\ipykernel_19672\3941891329.py:116: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[present_col] = df[flag_col].fillna(False)
#        SEQN  ALQ101  ALQ110       ALQ120Q  ALQ120U  ALQ130       ALQ140Q  \
# 0   51624.0     1.0     NaN  5.397605e-79      NaN     NaN           NaN
# 1   51625.0     NaN     NaN           NaN      NaN     NaN           NaN
# 2   51626.0     NaN     NaN           NaN      NaN     NaN           NaN
# 3   51627.0     NaN     NaN           NaN      NaN     NaN           NaN
# 4   51628.0     2.0     1.0  5.397605e-79      NaN     NaN           NaN
# 5   51629.0     1.0     NaN  4.000000e+00      2.0    19.0  4.000000e+00
# 6   51630.0     1.0     NaN  2.000000e+01      3.0     2.0  5.397605e-79
# 7   51631.0     NaN     NaN           NaN      NaN     NaN           NaN
# 8   51632.0     NaN     NaN           NaN      NaN     NaN           NaN
# 9   51633.0     1.0     NaN  1.000000e+00      1.0     1.0  5.397605e-79
# 10  51634.0     NaN     NaN           NaN      NaN     NaN           NaN
# 11  51635.0     2.0     1.0  5.397605e-79      NaN     NaN           NaN
# 12  51636.0     NaN     NaN           NaN      NaN     NaN           NaN
# 13  51637.0     NaN     NaN           NaN      NaN     NaN           NaN
# 14  51638.0     NaN     NaN           NaN      NaN     NaN           NaN
# 15  51639.0     NaN     NaN           NaN      NaN     NaN           NaN
# 16  51640.0     NaN     NaN           NaN      NaN     NaN           NaN
# 17  51641.0     NaN     NaN           NaN      NaN     NaN           NaN
# 18  51642.0     NaN     NaN           NaN      NaN     NaN           NaN
# 19  51643.0     2.0     1.0  5.397605e-79      NaN     NaN           NaN
#
#     ALQ140U  ALQ150 SEQN_in_alcohol_ALQ_C  ...  WHQ150  \
# 0       NaN     1.0                  True  ...    34.0
# 1       NaN     NaN                   NaN  ...     NaN
# 2       NaN     NaN                   NaN  ...     NaN
# 3       NaN     NaN                   NaN  ...     NaN
# 4       NaN     2.0                  True  ...    57.0
# 5       2.0     2.0                  True  ...    21.0
# 6       NaN     2.0                  True  ...    49.0
# 7       NaN     NaN                   NaN  ...     NaN
# 8       NaN     NaN                   NaN  ...     NaN
# 9       NaN     2.0                  True  ...    70.0
# 10      NaN     NaN                   NaN  ...     NaN
# 11      NaN     2.0                  True  ...    55.0
# 12      NaN     NaN                   NaN  ...     NaN
# 13      NaN     NaN                   NaN  ...    35.0
# 14      NaN     NaN                   NaN  ...     NaN
# 15      NaN     NaN                   NaN  ...     NaN
# 16      NaN     NaN                   NaN  ...     NaN
# 17      NaN     NaN                   NaN  ...     NaN
# 18      NaN     NaN                   NaN  ...     NaN
# 19      NaN     2.0                  True  ...    42.0
#
#     SEQN_in_weight_history_WHQ_C  present_alcohol_ALQ_C  \
# 0                           True                   True
# 1                            NaN                  False
# 2                           True                  False
# 3                            NaN                  False
# 4                           True                   True
# 5                           True                   True
# 6                           True                   True
# 7                            NaN                  False
# 8                            NaN                  False
# 9                           True                   True
# 10                           NaN                  False
# 11                          True                   True
# 12                           NaN                  False
# 13                          True                  False
# 14                           NaN                  False
# 15                           NaN                  False
# 16                          True                  False
# 17                           NaN                  False
# 18                           NaN                  False
# 19                          True                   True
#
#     present_blood_pressure_cholesterol_BPQ_C  present_diabetes_DIQ_C  \
# 0                                       True                    True
# 1                                      False                    True
# 2                                       True                    True
# 3                                      False                    True
# 4                                       True                    True
# 5                                       True                    True
# 6                                       True                    True
# 7                                      False                    True
# 8                                      False                    True
# 9                                       True                    True
# 10                                     False                    True
# 11                                      True                    True
# 12                                     False                    True
# 13                                      True                    True
# 14                                     False                    True
# 15                                     False                    True
# 16                                      True                    True
# 17                                     False                    True
# 18                                     False                    True
# 19                                      True                    True
#
#     present_health_insurance_HIQ_C  present_hospital_access_HUQ_C  \
# 0                             True                           True
# 1                             True                           True
# 2                             True                           True
# 3                             True                           True
# 4                             True                           True
# 5                             True                           True
# 6                             True                           True
# 7                             True                           True
# 8                             True                           True
# 9                             True                           True
# 10                            True                           True
# 11                            True                           True
# 12                            True                           True
# 13                            True                           True
# 14                            True                           True
# 15                            True                           True
# 16                            True                           True
# 17                            True                           True
# 18                            True                           True
# 19                            True                           True
#
#     present_smoking_SMQ_C  present_household_smokers_SMQFAM_C  \
# 0                    True                                True
# 1                   False                                True
# 2                    True                                True
# 3                   False                                True
# 4                    True                                True
# 5                    True                                True
# 6                    True                                True
# 7                   False                                True
# 8                   False                                True
# 9                    True                                True
# 10                  False                                True
# 11                   True                                True
# 12                  False                                True
# 13                   True                                True
# 14                  False                                True
# 15                  False                                True
# 16                   True                                True
# 17                   True                                True
# 18                  False                                True
# 19                   True                                True
#
#     present_weight_history_WHQ_C
# 0                           True
# 1                          False
# 2                           True
# 3                          False
# 4                           True
# 5                           True
# 6                           True
# 7                          False
# 8                          False
# 9                           True
# 10                         False
# 11                          True
# 12                         False
# 13                          True
# 14                         False
# 15                         False
# 16                          True
# 17                         False
# 18                         False
# 19                          True
#
# [20 rows x 190 columns]
# Unique SEQN count: 10537
# Final shape: (10537, 190)
# 📋 Final Columns After Merge + Rename:
# ['SEQN', 'ALQ101_had_at_least_12_alcohol_drinks_lifetime', 'ALQ110_had_at_least_12_alcohol_drinks_past_year', 'ALQ120Q_days_drank_alcohol_past_12_months_quantity', 'ALQ120U_days_drank_alcohol_past_12_months_unit', 'ALQ130_average_drinks_per_drinking_day', 'ALQ140Q_days_had_5_or_more_drinks_quantity', 'ALQ140U_days_had_5_or_more_drinks_unit', 'ALQ150', 'SEQN_in_alcohol_ALQ_C', 'BPQ020_ever_told_high_blood_pressure', 'BPQ030_told_high_blood_pressure_2_or_more_times', 'BPD035', 'BPQ040A_taking_prescription_for_hypertension', 'BPQ050A_now_taking_prescribed_hypertension_medicine', 'BPQ057', 'BPQ056', 'BPD058', 'BPQ059', 'BPQ060_ever_had_blood_cholesterol_checked', 'BPQ070_when_cholesterol_checked', 'BPQ080_ever_told_high_cholesterol', 'BPQ090A', 'BPQ090B', 'BPQ090C', 'BPQ090D_told_to_take_prescription_for_cholesterol', 'BPQ100A', 'BPQ100B', 'BPQ100C', 'BPQ100D', 'SEQN_in_blood_pressure_cholesterol_BPQ_C', 'DIQ010_ever_told_diabetes', 'DID040_age_when_first_told_diabetes', 'DIQ160', 'DIQ170_ever_told_pre_diabetes', 'DIQ180', 'DIQ050_now_taking_insulin', 'DID060_how_long_taking_insulin', 'DIQ060U_insulin_duration_unit', 'DIQ070_take_diabetic_pills', 'DIQ230', 'DIQ240', 'DID250', 'DID260', 'DIQ260U', 'DID341', 'DID350', 'DIQ350U', 'DIQ360', 'DIQ080', 'SEQN_in_diabetes_DIQ_C', 'HIQ011_covered_by_health_insurance', 'HIQ031A_private_insurance', 'HIQ031B_medicare', 'HIQ031C_medi_gap', 'HIQ031D_medicaid', 'HIQ031E_schip', 'HIQ031F_military_health_care', 'HIQ031H_state_sponsored_plan', 'HIQ031I_other_government_insurance', 'HIQ031J_single_service_plan', 'HIQ031AA_no_insurance_type', 'HIQ260_gap_in_health_insurance_past_year', 'HIQ105', 'HIQ270', 'HIQ210', 'SEQN_in_health_insurance_HIQ_C', 'HUQ010_general_health_condition', 'HUQ020', 'HUQ030_routine_place_to_go_for_healthcare', 'HUQ040_type_place_most_often_go_for_healthcare', 'HUQ050_times_received_healthcare_past_year', 'HUQ060_overnight_hospital_patient_past_year', 'HUQ071', 'HUD080', 'HUQ090', 'SEQN_in_hospital_access_HUQ_C', 'SMQ020_smoked_at_least_100_cigarettes_lifetime', 'SMD030_age_started_smoking_regularly', 'SMQ040_now_smoke_cigarettes', 'SMQ050Q_time_since_quit_smoking_quantity', 'SMQ050U_time_since_quit_smoking_unit', 'SMD055', 'SMD057', 'SMQ077', 'SMD641', 'SMD650', 'SMD093', 'SMDUPCA', 'SMD100BR', 'SMD100FL', 'SMD100MN', 'SMD100LN', 'SMD100TR', 'SMD100NI', 'SMD100CO', 'SMQ620', 'SMD630', 'SMQ660', 'SMQ664M', 'SMQ664C', 'SMQ664W', 'SMQ664B', 'SMQ664O', 'SMQ666M', 'SMQ666C', 'SMQ666K', 'SMQ666W', 'SMQ666B', 'SMQ666S', 'SMQ666O', 'SMQ670', 'SMAQUEX2', 'SEQN_in_smoking_SMQ_C', 'SMD410_number_of_smokers_in_home', 'SMD415_number_of_people_who_smoke_inside_home', 'SMD415A', 'SMD430', 'SEQN_in_household_smokers_SMQFAM_C', 'WHD010_current_self_reported_height_inches', 'WHD020_current_self_reported_weight_pounds', 'WHQ030_how_do_you_consider_your_weight', 'WHQ040_like_to_weigh_more_less_same', 'WHD045', 'WHD050_self_reported_weight_1_year_ago_pounds', 'WHQ060_weight_change_intentional', 'WHQ070_tried_to_lose_weight_past_year', 'WHD080A_weight_loss_method_ate_less_food', 'WHD080B_weight_loss_method_switched_foods', 'WHD080C_weight_loss_method_exercise', 'WHD080D', 'WHD080E', 'WHD080F', 'WHD080G', 'WHD080H', 'WHD080I', 'WHD080J', 'WHD080K', 'WHD080L', 'WHD080M', 'WHD080N', 'WHD080O', 'WHD080P', 'WHD080Q', 'WHD080R', 'WHD080S', 'WHD080T', 'WHQ270', 'WHQ280A', 'WHQ280B', 'WHQ280C', 'WHQ280D', 'WHQ280E', 'WHQ090', 'WHD100A', 'WHD100B', 'WHD100C', 'WHD100D', 'WHD100E', 'WHD100F', 'WHD100G', 'WHD100H', 'WHD100I', 'WHD100J', 'WHD100K', 'WHD100L', 'WHD100M', 'WHD100N', 'WHD100O', 'WHD100P', 'WHD100Q', 'WHD100R', 'WHD100S', 'WHD100T', 'WHQ210', 'WHD220', 'WHD110_self_reported_weight_10_years_ago_pounds', 'WHD120', 'WHD130', 'WHD140', 'WHQ150', 'SEQN_in_weight_history_WHQ_C', 'present_alcohol_ALQ_C', 'present_blood_pressure_cholesterol_BPQ_C', 'present_diabetes_DIQ_C', 'present_health_insurance_HIQ_C', 'present_hospital_access_HUQ_C', 'present_smoking_SMQ_C', 'present_household_smokers_SMQFAM_C',  ...
#
# 📊 Final Shape: (10537, 190)
# Unique SEQN count: 10537
#        SEQN  ALQ101_had_at_least_12_alcohol_drinks_lifetime  \
# 0   51624.0                                             1.0
# 1   51625.0                                             NaN
# 2   51626.0                                             NaN
# 3   51627.0                                             NaN
# 4   51628.0                                             2.0
# 5   51629.0                                             1.0
# 6   51630.0                                             1.0
# 7   51631.0                                             NaN
# 8   51632.0                                             NaN
# 9   51633.0                                             1.0
# 10  51634.0                                             NaN
# 11  51635.0                                             2.0
# 12  51636.0                                             NaN
# 13  51637.0                                             NaN
# 14  51638.0                                             NaN
# 15  51639.0                                             NaN
# 16  51640.0                                             NaN
# 17  51641.0                                             NaN
# 18  51642.0                                             NaN
# 19  51643.0                                             2.0
#
#     ALQ110_had_at_least_12_alcohol_drinks_past_year  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               1.0
# 5                                               NaN
# 6                                               NaN
# 7                                               NaN
# 8                                               NaN
# 9                                               NaN
# 10                                              NaN
# 11                                              1.0
# 12                                              NaN
# 13                                              NaN
# 14                                              NaN
# 15                                              NaN
# 16                                              NaN
# 17                                              NaN
# 18                                              NaN
# 19                                              1.0
#
#     ALQ120Q_days_drank_alcohol_past_12_months_quantity  \
# 0                                        5.397605e-79
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                        5.397605e-79
# 5                                        4.000000e+00
# 6                                        2.000000e+01
# 7                                                 NaN
# 8                                                 NaN
# 9                                        1.000000e+00
# 10                                                NaN
# 11                                       5.397605e-79
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                       5.397605e-79
#
#     ALQ120U_days_drank_alcohol_past_12_months_unit  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
# 5                                              2.0
# 6                                              3.0
# 7                                              NaN
# 8                                              NaN
# 9                                              1.0
# 10                                             NaN
# 11                                             NaN
# 12                                             NaN
# 13                                             NaN
# 14                                             NaN
# 15                                             NaN
# 16                                             NaN
# 17                                             NaN
# 18                                             NaN
# 19                                             NaN
#
#     ALQ130_average_drinks_per_drinking_day  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
# 5                                     19.0
# 6                                      2.0
# 7                                      NaN
# 8                                      NaN
# 9                                      1.0
# 10                                     NaN
# 11                                     NaN
# 12                                     NaN
# 13                                     NaN
# 14                                     NaN
# 15                                     NaN
# 16                                     NaN
# 17                                     NaN
# 18                                     NaN
# 19                                     NaN
#
#     ALQ140Q_days_had_5_or_more_drinks_quantity  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
# 5                                 4.000000e+00
# 6                                 5.397605e-79
# 7                                          NaN
# 8                                          NaN
# 9                                 5.397605e-79
# 10                                         NaN
# 11                                         NaN
# 12                                         NaN
# 13                                         NaN
# 14                                         NaN
# 15                                         NaN
# 16                                         NaN
# 17                                         NaN
# 18                                         NaN
# 19                                         NaN
#
#     ALQ140U_days_had_5_or_more_drinks_unit  ALQ150 SEQN_in_alcohol_ALQ_C  ...  \
# 0                                      NaN     1.0                  True  ...
# 1                                      NaN     NaN                   NaN  ...
# 2                                      NaN     NaN                   NaN  ...
# 3                                      NaN     NaN                   NaN  ...
# 4                                      NaN     2.0                  True  ...
# 5                                      2.0     2.0                  True  ...
# 6                                      NaN     2.0                  True  ...
# 7                                      NaN     NaN                   NaN  ...
# 8                                      NaN     NaN                   NaN  ...
# 9                                      NaN     2.0                  True  ...
# 10                                     NaN     NaN                   NaN  ...
# 11                                     NaN     2.0                  True  ...
# 12                                     NaN     NaN                   NaN  ...
# 13                                     NaN     NaN                   NaN  ...
# 14                                     NaN     NaN                   NaN  ...
# 15                                     NaN     NaN                   NaN  ...
# 16                                     NaN     NaN                   NaN  ...
# 17                                     NaN     NaN                   NaN  ...
# 18                                     NaN     NaN                   NaN  ...
# 19                                     NaN     2.0                  True  ...
#
#     WHQ150  SEQN_in_weight_history_WHQ_C  present_alcohol_ALQ_C  \
# 0     34.0                          True                   True
# 1      NaN                           NaN                  False
# 2      NaN                          True                  False
# 3      NaN                           NaN                  False
# 4     57.0                          True                   True
# 5     21.0                          True                   True
# 6     49.0                          True                   True
# 7      NaN                           NaN                  False
# 8      NaN                           NaN                  False
# 9     70.0                          True                   True
# 10     NaN                           NaN                  False
# 11    55.0                          True                   True
# 12     NaN                           NaN                  False
# 13    35.0                          True                  False
# 14     NaN                           NaN                  False
# 15     NaN                           NaN                  False
# 16     NaN                          True                  False
# 17     NaN                           NaN                  False
# 18     NaN                           NaN                  False
# 19    42.0                          True                   True
#
#     present_blood_pressure_cholesterol_BPQ_C  present_diabetes_DIQ_C  \
# 0                                       True                    True
# 1                                      False                    True
# 2                                       True                    True
# 3                                      False                    True
# 4                                       True                    True
# 5                                       True                    True
# 6                                       True                    True
# 7                                      False                    True
# 8                                      False                    True
# 9                                       True                    True
# 10                                     False                    True
# 11                                      True                    True
# 12                                     False                    True
# 13                                      True                    True
# 14                                     False                    True
# 15                                     False                    True
# 16                                      True                    True
# 17                                     False                    True
# 18                                     False                    True
# 19                                      True                    True
#
#     present_health_insurance_HIQ_C  present_hospital_access_HUQ_C  \
# 0                             True                           True
# 1                             True                           True
# 2                             True                           True
# 3                             True                           True
# 4                             True                           True
# 5                             True                           True
# 6                             True                           True
# 7                             True                           True
# 8                             True                           True
# 9                             True                           True
# 10                            True                           True
# 11                            True                           True
# 12                            True                           True
# 13                            True                           True
# 14                            True                           True
# 15                            True                           True
# 16                            True                           True
# 17                            True                           True
# 18                            True                           True
# 19                            True                           True
#
#     present_smoking_SMQ_C  present_household_smokers_SMQFAM_C  \
# 0                    True                                True
# 1                   False                                True
# 2                    True                                True
# 3                   False                                True
# 4                    True                                True
# 5                    True                                True
# 6                    True                                True
# 7                   False                                True
# 8                   False                                True
# 9                    True                                True
# 10                  False                                True
# 11                   True                                True
# 12                  False                                True
# 13                   True                                True
# 14                  False                                True
# 15                  False                                True
# 16                   True                                True
# 17                   True                                True
# 18                  False                                True
# 19                   True                                True
#
#     present_weight_history_WHQ_C
# 0                           True
# 1                          False
# 2                           True
# 3                          False
# 4                           True
# 5                           True
# 6                           True
# 7                          False
# 8                          False
# 9                           True
# 10                         False
# 11                          True
# 12                         False
# 13                          True
# 14                         False
# 15                         False
# 16                          True
# 17                         False
# 18                         False
# 19                          True
#
# [20 rows x 190 columns]
# 📊 Data Availability Matrix:
#        SEQN present_alcohol_ALQ_C present_blood_pressure_cholesterol_BPQ_C  \
# 0   51624.0                  True                                     True
# 1   51625.0                 False                                    False
# 2   51626.0                 False                                     True
# 3   51627.0                 False                                    False
# 4   51628.0                  True                                     True
# 5   51629.0                  True                                     True
# 6   51630.0                  True                                     True
# 7   51631.0                 False                                    False
# 8   51632.0                 False                                    False
# 9   51633.0                  True                                     True
# 10  51634.0                 False                                    False
# 11  51635.0                  True                                     True
# 12  51636.0                 False                                    False
# 13  51637.0                 False                                     True
# 14  51638.0                 False                                    False
# 15  51639.0                 False                                    False
# 16  51640.0                 False                                     True
# 17  51641.0                 False                                    False
# 18  51642.0                 False                                    False
# 19  51643.0                  True                                     True
#
#    present_diabetes_DIQ_C  present_health_insurance_HIQ_C  \
# 0                    True                            True
# 1                    True                            True
# 2                    True                            True
# 3                    True                            True
# 4                    True                            True
# 5                    True                            True
# 6                    True                            True
# 7                    True                            True
# 8                    True                            True
# 9                    True                            True
# 10                   True                            True
# 11                   True                            True
# 12                   True                            True
# 13                   True                            True
# 14                   True                            True
# 15                   True                            True
# 16                   True                            True
# 17                   True                            True
# 18                   True                            True
# 19                   True                            True
#
#     present_hospital_access_HUQ_C present_smoking_SMQ_C  \
# 0                            True                  True
# 1                            True                 False
# 2                            True                  True
# 3                            True                 False
# 4                            True                  True
# 5                            True                  True
# 6                            True                  True
# 7                            True                 False
# 8                            True                 False
# 9                            True                  True
# 10                           True                 False
# 11                           True                  True
# 12                           True                 False
# 13                           True                  True
# 14                           True                 False
# 15                           True                 False
# 16                           True                  True
# 17                           True                  True
# 18                           True                 False
# 19                           True                  True
#
#     present_household_smokers_SMQFAM_C present_weight_history_WHQ_C
# 0                                 True                         True
# 1                                 True                        False
# 2                                 True                         True
# 3                                 True                        False
# 4                                 True                         True
# 5                                 True                         True
# 6                                 True                         True
# 7                                 True                        False
# 8                                 True                        False
# 9                                 True                         True
# 10                                True                        False
# 11                                True                         True
# 12                                True                        False
# 13                                True                         True
# 14                                True                        False
# 15                                True                        False
# 16                                True                         True
# 17                                True                        False
# 18                                True                        False
# 19                                True                         True
#                             dataset  available_records  missing_records  \
# 0                     alcohol_ALQ_C               6059             4478
# 1  blood_pressure_cholesterol_BPQ_C               6889             3648
# 2                    diabetes_DIQ_C              10109              428
# 3            health_insurance_HIQ_C              10537                0
# 4             hospital_access_HUQ_C              10537                0
# 5                     smoking_SMQ_C               7528             3009
# 6        household_smokers_SMQFAM_C              10537                0
# 7              weight_history_WHQ_C               6889             3648
#
#    availability_percent
# 0                 57.50
# 1                 65.38
# 2                 95.94
# 3                100.00
# 4                100.00
# 5                 71.44
# 6                100.00
# 7                 65.38
# ✅ Saved to:
# C:\Users\NVK00\Desktop\MyData\Projects\Clinical_Neighbourhood_ML_Data_Predictor\data\processed\NHANE_Questionnair\neighbourhood_nhanes_questionnaire_2009_2010.csv
