# %%
# =================================================================================================
# PART 1 - Demographics part one will aggregate all data into 1 file
# Raw data : This is All Demographics data from NHANES
# Previously Done : To run this file, the list of CSVs below have processed datasets yearly into saperate notebooks
# Purpose : This Aggregator program combining all Demographics data 2004-2014 into one as below will get all yearly csvs and create one dataset file 2003-2014 
# Specification : Each NHANE dataset has SEQN "Participent ID" which is uniqud id for labs. 
# Files Used :  DEMO_C.csv, DEMO_D.csv, DEMO_E.csv,DEMO_F.csv, DEMO_G.csv, DEMO_H.csv
# Data Availability Matrix : https://docs.google.com/spreadsheets/d/1E_zIzHZsEs0o-XWx8HbTN7ZPODge7EEC/edit?gid=1721397761#gid=1721397761
# Source Site : https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public
# Developer Notes :  The notebook had created for windows desktop environment with Python3.
# File Creator : Neha Khairnar
# ===================================================================================================
# 📦 Step 1: Imports
# =========================
import pandas as pd
from pathlib import Path

# =========================
# 📂 Step 2: Define Paths
# =========================
BASE_DIR = Path().resolve().parent
DATA_DIR = BASE_DIR / "data" / "2015_2016" / "Demographics"

# List all demographic files (update names as per your files)
FILES = [
    "DEMO_I_corrected.csv",
    # "DEMO_D.csv",
    # "DEMO_E.csv",
    # "DEMO_F.csv",
    # "DEMO_G.csv",
    # "DEMO_H.csv"
]


# =========================
# 📥 Step 3: Load & Append
# =========================
dfs = []
for file in FILES:
    path = DATA_DIR / file
    #df = pd.read_csv(path)  
    
    df = pd.read_csv(
        path,
        dtype=str,
        keep_default_na=False
    )

    # Standardize column names
    df.columns = df.columns.str.upper()
    # Optional: Add survey cycle column
    if file == "DEMO_I_corrected.csv":
        df["CYCLE"] = "2015-2016"
        df["Source"] = "DEMO_I"
    print(file, "shape:", df.shape)
    dfs.append(df)


# =========================
# 🔗 Step 4: Concatenate (Append)
# =========================
demo_all = pd.concat(dfs, axis=0, ignore_index=True)

# =========================
# 👀 Step 5: Preview
# =========================
print("Combined Demographics Preview:")
display(demo_all.head(10))

# =========================
# 📊 Step 6: Validation
# =========================
print("Final shape:", demo_all.shape)

# Check duplicate SEQN (should be unique across cycles)
duplicates = demo_all["SEQN"].duplicated().sum()
print("Duplicate SEQN:", duplicates)

# =========================
# 🧼 Step 7: Optional Cleaning
# =========================
# Drop exact duplicates if any
demo_all = demo_all.drop_duplicates()

# =========================
# 💾 Step 8: Save Output
# =========================
OUTPUT_DIR = BASE_DIR / "data" / "processed_v3/2015_2016"
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)

demo_all.to_csv(OUTPUT_DIR / "neighbourhood_nhanes_demographics_2015_2016_raw_corrected.csv", index=False)

print("Saved to:")
print(OUTPUT_DIR / "neighbourhood_nhanes_demographics_2015_2016_raw_corrected.csv")
# Out:
# DEMO_I_corrected.csv shape: (9971, 49)
# Combined Demographics Preview:
#     SEQN SDDSRVYR RIDSTATR RIAGENDR RIDAGEYR RIDAGEMN RIDRETH1 RIDRETH3  \
# 0  83732        9        2        1       62                 3        3
# 1  83733        9        2        1       53                 3        3
# 2  83734        9        2        1       78                 3        3
# 3  83735        9        2        2       56                 3        3
# 4  83736        9        2        2       42                 4        4
# 5  83737        9        2        2       72                 1        1
# 6  83738        9        2        2       11                 1        1
# 7  83739        9        2        1        4                 3        3
# 8  83740        9        2        1        1       13        2        2
# 9  83741        9        2        1       22                 4        4
#
#   RIDEXMON RIDEXAGM  ... DMDHSEDU       WTINT2YR       WTMEC2YR SDMVPSU  \
# 0        1           ...        3  134671.370419  135629.507405       1
# 1        1           ...            24328.560239   25282.425927       1
# 2        2           ...        3   12400.008522   12575.838818       1
# 3        2           ...           102717.995647  102078.634508       1
# 4        2           ...            17627.674984   18234.736219       2
# 5        1           ...        5   11252.311968   10878.684022       1
# 6        1      141  ...             9964.725426    9860.624532       1
# 7        2       54  ...        5   44749.889547   46173.307234       2
# 8        2       14  ...             9891.944044    10963.31371       1
# 9        1           ...        5   37043.087007   39353.307397       2
#
#   SDMVSTRA INDHHIN2 INDFMIN2 INDFMPIR      CYCLE  Source
# 0      125       10       10     4.39  2015-2016  DEMO_I
# 1      125        4        4     1.32  2015-2016  DEMO_I
# 2      131        5        5     1.51  2015-2016  DEMO_I
# 3      131       10       10      5.0  2015-2016  DEMO_I
# 4      126        7        7     1.23  2015-2016  DEMO_I
# 5      128       14       14     2.82  2015-2016  DEMO_I
# 6      120        6        6     1.18  2015-2016  DEMO_I
# 7      124       15       15     4.22  2015-2016  DEMO_I
# 8      119       77       77           2015-2016  DEMO_I
# 9      128        7        7     2.08  2015-2016  DEMO_I
#
# [10 rows x 49 columns]
# Final shape: (9971, 49)
# Duplicate SEQN: 0
# Saved to:
# C:\Users\User\Desktop\Projects\Clinical_Neighbourhood_ML_Data_Predictor\Clinical_Neighbourhood_ML_Data_Predictor\data\processed_v3\2015_2016\neighbourhood_nhanes_demographics_2015_2016_raw_corrected.csv
