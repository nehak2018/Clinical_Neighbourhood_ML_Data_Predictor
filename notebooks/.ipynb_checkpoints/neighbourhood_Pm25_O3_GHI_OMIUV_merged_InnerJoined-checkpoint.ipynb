# %%
# =========================
# 📦 Step 1: Imports
# =========================
import pandas as pd
from pathlib import Path


# =========================
# 📂 Step 2: Paths
# =========================
BASE_DIR = Path().resolve().parent
DATA_DIR = BASE_DIR / "data" / "processed"

pm25 = pd.read_csv(DATA_DIR / "neighbourhood_pm25_yearly.csv")
o3 = pd.read_csv(DATA_DIR / "neighbourhood_o3_yearly.csv")
ghi = pd.read_csv(DATA_DIR / "neighbourhood_ghi_yearly.csv")
omiuv = pd.read_csv(DATA_DIR / "neighbourhood_omiuv_yearly.csv")


# =========================
# 📊 Step 3: Filter Common Years (2004–2012)
# =========================
COMMON_START = 2004
COMMON_END = 2012

pm25 = pm25[(pm25["year"] >= COMMON_START) & (pm25["year"] <= COMMON_END)]
o3   = o3[(o3["year"] >= COMMON_START) & (o3["year"] <= COMMON_END)]
ghi  = ghi[(ghi["year"] >= COMMON_START) & (ghi["year"] <= COMMON_END)]
omiuv= omiuv[(omiuv["year"] >= COMMON_START) & (omiuv["year"] <= COMMON_END)]


# =========================
# 🧹 Step 4: Standardize Column Names
# =========================

# PM2.5
pm25 = pm25.rename(columns={
    "PM25_max": "PM25_max_pred",
    "PM25_median": "PM25_med_pred",
    "PM25_mean": "PM25_mean_pred",
    "PM25_pop": "PM25_pop_pred"
})

# Ozone
o3 = o3.rename(columns={
    "O3_max": "O3_max_pred",
    "O3_median": "O3_med_pred",
    "O3_mean": "O3_mean_pred",
    "O3_pop": "O3_pop_pred"
})

# GHI
ghi = ghi.rename(columns={
    "GHI_mean": "GHI"
})

# OMIUV
omiuv = omiuv.rename(columns={
    "EDD_mean": "OMIUV_edd",
    "EDR_mean": "OMIUV_edr",
    "I305_mean": "OMIUV_i305",
    "I310_mean": "OMIUV_i310",
    "I324_mean": "OMIUV_i324",
    "I380_mean": "OMIUV_i380"
})


# =========================
# 🔗 Step 5: INNER MERGE
# =========================
df = pm25.merge(o3, on=["year", "state_fips", "county_fips"], how="inner")
df = df.merge(ghi, on=["year", "state_fips", "county_fips"], how="inner")
df = df.merge(omiuv, on=["year", "state_fips", "county_fips"], how="inner")


# =========================
# 🧱 Step 6: Rename FIPS
# =========================
df = df.rename(columns={
    "state_fips": "statefips",
    "county_fips": "countyfips"
})


# =========================
# 🧾 Step 7: Select Final Columns
# =========================
final_cols = [
    "year", "statefips", "countyfips",
    
    "PM25_max_pred", "PM25_med_pred", "PM25_mean_pred", "PM25_pop_pred",
    
    "O3_max_pred", "O3_med_pred", "O3_mean_pred", "O3_pop_pred",
    
    "GHI",
    
    "OMIUV_edd", "OMIUV_edr", "OMIUV_i305",
    "OMIUV_i310", "OMIUV_i324", "OMIUV_i380"
]

df_final = df[final_cols]


# =========================
# 👀 Step 8: Preview
# =========================
print("Final Dataset Preview:")
display(df_final.head(10))


# =========================
# 📊 Step 9: Validation
# =========================
print("Shape:", df_final.shape)
print(df_final.info())

# Check missing values (should be minimal or none)
print("\nMissing values:\n", df_final.isnull().sum())


# =========================
# 💾 Step 10: Save Final Dataset
# =========================
OUTPUT_PATH = DATA_DIR / "neighborhood_environmental_2004_2012.csv"

df_final.to_csv(OUTPUT_PATH, index=False)

print("✅ Saved to:", OUTPUT_PATH)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 15
#      12 DATA_DIR = BASE_DIR / "data" / "processed"
#      14 pm25 = pd.read_csv(DATA_DIR / "neighbourhood_pm25_yearly.csv")
# ---> 15 o3 = pd.read_csv(DATA_DIR / "neighbourhood_ozone_yearly.csv")
#      16 ghi = pd.read_csv(DATA_DIR / "neighbourhood_ghi_yearly.csv")
#      17 omiuv = pd.read_csv(DATA_DIR / "neighbourhood_omiuv_yearly.csv")
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\parsers\readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     861 kwds_defaults = _refine_defaults_read(
#     862     dialect,
#     863     delimiter,
#    (...)    869     dtype_backend=dtype_backend,
#     870 )
#     871 kwds.update(kwds_defaults)
# --> 873 return _read(filepath_or_buffer, kwds)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\parsers\readers.py:300, in _read(filepath_or_buffer, kwds)
#     297 _validate_names(kwds.get("names", None))
#     299 # Create the parser.
# --> 300 parser = TextFileReader(filepath_or_buffer, **kwds)
#     302 if chunksize or iterator:
#     303     return parser
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\parsers\readers.py:1645, in TextFileReader.__init__(self, f, engine, **kwds)
#    1642     self.options["has_index_names"] = kwds["has_index_names"]
#    1644 self.handles: IOHandles | None = None
# -> 1645 self._engine = self._make_engine(f, self.engine)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\parsers\readers.py:1904, in TextFileReader._make_engine(self, f, engine)
#    1902     if "b" not in mode:
#    1903         mode += "b"
# -> 1904 self.handles = get_handle(
#    1905     f,
#    1906     mode,
#    1907     encoding=self.options.get("encoding", None),
#    1908     compression=self.options.get("compression", None),
#    1909     memory_map=self.options.get("memory_map", False),
#    1910     is_text=is_text,
#    1911     errors=self.options.get("encoding_errors", "strict"),
#    1912     storage_options=self.options.get("storage_options", None),
#    1913 )
#    1914 assert self.handles is not None
#    1915 f = self.handles.handle
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\common.py:926, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     921 elif isinstance(handle, str):
#     922     # Check whether the filename is to be opened in binary mode.
#     923     # Binary mode does not support 'encoding' and 'newline'.
#     924     if ioargs.encoding and "b" not in ioargs.mode:
#     925         # Encoding
# --> 926         handle = open(
#     927             handle,
#     928             ioargs.mode,
#     929             encoding=ioargs.encoding,
#     930             errors=errors,
#     931             newline="",
#     932         )
#     933     else:
#     934         # Binary mode
#     935         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Users\\NVK00\\Desktop\\MyData\\Projects\\Clinical_Neighbourhood_ML_Data_Predictor\\data\\processed\\neighbourhood_ozone_yearly.csv'
