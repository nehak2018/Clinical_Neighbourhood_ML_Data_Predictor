# %%
# =================================================================================================
# PART 1 - Demographics part one will aggregate all data into 1 file
# Raw data : This is All Demographics data from NHANES
# Previously Done : To run this file, the list of CSVs below have processed datasets yearly into saperate notebooks
# Purpose : This Aggregator program combining all Demographics data 2004-2014 into one as below will get all yearly csvs and create one dataset file 2003-2014 
# Specification : Each NHANE dataset has SEQN "Participent ID" which is uniqud id for labs. 
# Files Used :  DEMO_C.csv, DEMO_D.csv, DEMO_E.csv,DEMO_F.csv, DEMO_G.csv, DEMO_H.csv
# Data Availability Matrix : https://docs.google.com/spreadsheets/d/1E_zIzHZsEs0o-XWx8HbTN7ZPODge7EEC/edit?gid=1721397761#gid=1721397761
# Source Site : https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public
# Developer Notes :  The notebook had created for windows desktop environment with Python3.
# File Creator : Neha Khairnar
# ===================================================================================================
# 📦 Step 1: Imports
# =========================
import pandas as pd
from pathlib import Path

# =========================
# 📂 Step 2: Define Paths
# =========================
BASE_DIR = Path().resolve().parent
DATA_DIR = BASE_DIR / "data" / "2003_2004" / "Demographics"

# List all demographic files (update names as per your files)
FILES = [
    "DEMO_C_corrected.csv",
    # "DEMO_D.csv",
    # "DEMO_E.csv",
    # "DEMO_F.csv",
    # "DEMO_G.csv",
    # "DEMO_H.csv"
]


# =========================
# 📥 Step 3: Load & Append
# =========================
dfs = []
for file in FILES:
    path = DATA_DIR / file
    #df = pd.read_csv(path)  
    
    df = pd.read_csv(
        path,
        dtype=str,
        keep_default_na=False
    )

    # Standardize column names
    df.columns = df.columns.str.upper()
    # Optional: Add survey cycle column
    if file == "DEMO_C_corrected.csv":
        df["CYCLE"] = "2003-2004"
        df["Source"] = "DEMO_C"
    print(file, "shape:", df.shape)
    dfs.append(df)


# =========================
# 🔗 Step 4: Concatenate (Append)
# =========================
demo_all = pd.concat(dfs, axis=0, ignore_index=True)

# =========================
# 👀 Step 5: Preview
# =========================
print("Combined Demographics Preview:")
display(demo_all.head(10))

# =========================
# 📊 Step 6: Validation
# =========================
print("Final shape:", demo_all.shape)

# Check duplicate SEQN (should be unique across cycles)
duplicates = demo_all["SEQN"].duplicated().sum()
print("Duplicate SEQN:", duplicates)

# =========================
# 🧼 Step 7: Optional Cleaning
# =========================
# Drop exact duplicates if any
demo_all = demo_all.drop_duplicates()

# =========================
# 💾 Step 8: Save Output
# =========================
OUTPUT_DIR = BASE_DIR / "data" / "processed_v3"
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)

demo_all.to_csv(OUTPUT_DIR / "neighbourhood_nhanes_demographics_2003_2004_raw_corrected.csv", index=False)

print("Saved to:")
print(OUTPUT_DIR / "neighbourhood_nhanes_demographics_2003_2004_raw_corrected.csv")
# Out:
# DEMO_C_corrected.csv shape: (10122, 46)
# Combined Demographics Preview:
#     SEQN SDDSRVYR RIDSTATR RIDEXMON RIAGENDR RIDAGEYR RIDAGEMN RIDAGEEX  \
# 0  21005        3        2        1        1       19      232      233
# 1  21006        3        2        2        2       16      203      205
# 2  21007        3        2        1        2       14      172      172
# 3  21008        3        2        2        1       17      208      209
# 4  21009        3        2        2        1       55      671      672
# 5  21010        3        2        2        2       52      633      634
# 6  21011        3        2        1        1        0        3        4
# 7  21012        3        2        2        1       63      765      766
# 8  21013        3        2        1        2       13      163      164
# 9  21014        3        2        2        1        3       42       42
#
#   RIDRETH1 RIDRETH2  ... MIALANG MIAPROXY MIAINTRP AIALANG  \
# 0        4        2  ...       1        2        2       1
# 1        4        2  ...       1        2        2       1
# 2        3        1  ...       1        2        2       1
# 3        4        2  ...       1        2        2       1
# 4        3        1  ...       1        2        2       1
# 5        3        1  ...       1        2        2       1
# 6        1        3  ...
# 7        4        2  ...
# 8        4        2  ...       1        2        2       1
# 9        4        2  ...
#
#              WTINT2YR           WTMEC2YR SDMVPSU SDMVSTRA      CYCLE  Source
# 0    5512.32094860935  5824.782465454041       2       39  2003-2004  DEMO_C
# 1   5422.140452659803  5564.039714652058       1       41  2003-2004  DEMO_C
# 2        39764.177412       40591.066325       2       35  2003-2004  DEMO_C
# 3   5599.499351374193  5696.750595869874       1       32  2003-2004  DEMO_C
# 4        97593.678977       97731.727244       2       31  2003-2004  DEMO_C
# 5        39599.362689       43286.576474       1       29  2003-2004  DEMO_C
# 6          1647.61769        1692.168138       2       40  2003-2004  DEMO_C
# 7         12629.44048       12947.338142       2       33  2003-2004  DEMO_C
# 8  7174.3710365355055  7304.945502641202       1       37  2003-2004  DEMO_C
# 9         7498.031463        8385.245979       1       33  2003-2004  DEMO_C
#
# [10 rows x 46 columns]
# Final shape: (10122, 46)
# Duplicate SEQN: 0
# Saved to:
# C:\Users\User\Desktop\Projects\Clinical_Neighbourhood_ML_Data_Predictor\Clinical_Neighbourhood_ML_Data_Predictor\data\processed_v3\neighbourhood_nhanes_demographics_2003_2004_raw_corrected.csv
