# %%
# =================================================================================================
# Raw data : This is Lab data from NHANES
# Purpose : Creating raw CSV file which converted from .xpt and generate ths Labs data.
# Specification : Each NHANE dataset has SEQN "Participent ID" which is uniqud id for labs. 
# Files Used :  L10AM_C.csv, L13_C.csv,PH_C.csv downloaded from Source 
# Data Dictinary : 
# Data Availability Matrix : 
# Source Site : 
# Developer Notes :  The notebook had created for windows desktop environment with Python3.
# File Creator : Neha Khairnar
# ===================================================================================================

# 📦 Step 1: Imports
import pandas as pd
from pathlib import Path
# # =================================================================================================
# 📂 Step 2: Paths below resolved for locally run datasets
#BASE_DIR = Path().resolve().parent
#DATA_DIR = BASE_DIR / "data" / "dataset"/ "NHANE_Continuous_DemographicsData_2003_2004_Labs"

# # =================================================================================================
# 📥 Step 3: Load ALL Files (NO COLUMN DROPPING)
# # =================================================================================================

glucose_cpep_insulin_file ="../data/Datasets/NHANE_Continuous_DemographicsData_2003_2004_Labs/L10AM_C.csv"
cholesterol_file = "../data/Datasets/NHANE_Continuous_DemographicsData_2003_2004_Labs/L13_C.csv"
fasting_q_file = "../data/Datasets/NHANE_Continuous_DemographicsData_2003_2004_Labs/PH_C.csv"

glucose_cpep_insulin = pd.read_csv(glucose_cpep_insulin_file)
chol = pd.read_csv(cholesterol_file)
fasting = pd.read_csv(fasting_q_file)

files = {
    "glucose_cpep_insulin_L10AM_C": glucose_cpep_insulin_file,
    "cholesterol_L13_C": cholesterol_file,
    "fasting_PH_C": fasting_q_file
}

# =================================================================================================
# 📊 Summary container uses above JSON for inspecting file purpose which
# # ===============================================================================================
summary = []
# =========================
# 🔁 Loop through files
# =========================
for name, path in files.items():
    df = pd.read_csv(path)
    summary.append({
        "file": name,
        "rows": df.shape[0],
        "columns": df.shape[1],
        "column_names": list(df.columns)
    })

# =========================
# 📋 Convert to DataFrame
# =========================
summary_df = pd.DataFrame(summary)

# =========================
# 👀 Display summary
# =========================
print("📊 NHANES File Structure Summary:\n")
display(summary_df[["file", "rows", "columns", "column_names"]])

# =========================
# 🧠 Print full column lists
# =========================
for i, row in summary_df.iterrows():
    print("\n" + "="*50)
    print("FILE:", row["file"])
    print("COLUMNS:", len(row["column_names"]))
    print(row["column_names"])

# =========================
# 🧹 Step 4: Standardize Column Names
# =========================
glucose_cpep_insulin.columns = glucose_cpep_insulin.columns.str.upper()
chol.columns = chol.columns.str.upper()
fasting.columns = fasting.columns.str.upper()

# =========================
# 🧠 STEP 1: SEQN presence in EACH dataset
# =========================

glucose_cpep_insulin["SEQN_in_glucose_cpep_insulin"] = glucose_cpep_insulin["SEQN"].notna()
chol["SEQN_in_chol"] = chol["SEQN"].notna()
fasting["SEQN_in_fasting"] = fasting["SEQN"].notna()

# ===================================================================================================
# 🔗 Step 5: Merge ALL columns (FULL OUTER JOIN) which will have unique sequence numbers with all values
# ===================================================================================================
df = glucose_cpep_insulin.merge(
        chol,
        on="SEQN",
        how="outer",
        suffixes=("", "_CHOL")
    ).merge(
        fasting,
        on="SEQN",
        how="outer",
        suffixes=("", "_FAST")
    )

# ===================================================================================================
# 🧠 Step 7: SEQN Presence Flags states that which SEQN is coming from which file for troubleshooting purpose.
# ===================================================================================================
df["present_glucose_cpep_insulin"] = df["SEQN_in_glucose_cpep_insulin"].fillna(False)
df["present_chol"] = df["SEQN_in_chol"].fillna(False)
df["present_fasting"] = df["SEQN_in_fasting"].fillna(False)
display(df.head(20))
print("Unique SEQN count:", df["SEQN"].nunique())


# ===================================================================================================
# 🧠 Step 8: Below map will REname the column name for reading purpose. Which may need to recode however, 
# it has naming convention of "Source_name"_"Actual_Description"
# ===================================================================================================

rename_map_glucose_cpep_insulin = {
    # ID
    "SEQN": "SEQN",
    
    # Weights
    "WTSAF2YR": "WTSAF2YR_fasting_subsample_weight_2yr",
   
    # Glucose
    "LBXGLU": "LBXGLU_plasma_glucose_mg_dl",
    "LBDGLUSI": "LBDGLUSI_plasma_glucose_mmol_l",

    # C-peptide
    "LBXCPSI": "LBXCPSI_c_peptide_si_nmol_l",

    # Insulin
    "LBXIN": "LBXIN_insulin_uu_ml",
    "LBDINSI": "LBDINSI_insulin_si_pmol_l"
}

# Safe rename (only existing columns)
df = df.rename(columns={k: v for k, v in rename_map_glucose_cpep_insulin.items() if k in df.columns})


# =========================
# 🧬 Cholesterol Rename Map (L13_C)
# =========================

rename_map_chol = {
    "SEQN": "SEQN",

    # Cholesterol (mg/dL)
    "LBXTC": "LBXTC_total_cholesterol_mg_dl",
    "LBXHDD": "LBXHDD_hdl_cholesterol_mg_dl",

    # Cholesterol (mmol/L)
    "LBDTCSI": "LBDTCSI_total_cholesterol_mmol_l",
    "LBDHDDSI": "LBDHDDSI_hdl_cholesterol_mmol_l"
}

df = df.rename(columns={k: v for k, v in rename_map_chol.items() if k in df.columns})

# =========================
# 🍽️ Fasting Questionnaire Rename Map (PH_C)
# =========================

rename_map_phc = {
    "SEQN": "SEQN",

    # Coffee / Tea
    "PHQ020": "PHQ020_coffee_tea_consumption_code",
    "PHACOFHR": "PHACOFHR_coffee_tea_fast_hours",
    "PHACOFMN": "PHACOFMN_coffee_tea_fast_minutes",

    # Alcohol
    "PHQ030": "PHQ030_alcohol_consumption_code",
    "PHAALCHR": "PHAALCHR_alcohol_fast_hours",
    "PHAALCMN": "PHAALCMN_alcohol_fast_minutes",

    # Gum / mints / cough drops
    "PHQ040": "PHQ040_gum_mint_cough_consumption_code",
    "PHAGUMHR": "PHAGUMHR_gum_mint_fast_hours",
    "PHAGUMMN": "PHAGUMMN_gum_mint_fast_minutes",

    # Antacids / laxatives
    "PHQ050": "PHQ050_antacid_laxative_consumption_code",
    "PHAANTHR": "PHAANTHR_antacid_fast_hours",
    "PHAANTMN": "PHAANTMN_antacid_fast_minutes",

    # Dietary supplements
    "PHQ060": "PHQ060_supplement_consumption_code",
    "PHASUPHR": "PHASUPHR_supplement_fast_hours",
    "PHASUPMN": "PHASUPMN_supplement_fast_minutes",

    # Total fasting duration
    "PHAFSTHR": "PHAFSTHR_total_fast_hours",
    "PHAFSTMN": "PHAFSTMN_total_fast_minutes",

    # Exam session
    "PHDSESN": "PHDSESN_exam_session"
}

df = df.rename(columns={k: v for k, v in rename_map_phc.items() if k in df.columns})


# ===================================================================================================
# 👀 Step 3: Validate result
# ===================================================================================================
print("📋 Final Columns After Merge + Rename:")
print(df.columns.tolist())
print("\n📊 Shape:", df.shape)

# ===================================================================================================
# 💾 Step 14: Save Final Output, Need to change if you are on SCHARE
# ===================================================================================================
OUTPUT_DIR = BASE_DIR / "data" / "processed"
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)

OUTPUT_PATH = OUTPUT_DIR / "neighbourhood_nhanes_labs_2003_2004.csv"

df.to_csv(OUTPUT_PATH, index=False)

print("\n✅ Saved to:")
print(OUTPUT_PATH)
# Out:
# 📊 NHANES File Structure Summary:
#                            file  rows  columns  \
# 0  glucose_cpep_insulin_L10AM_C  3356        7
# 1             cholesterol_L13_C  8556        5
# 2                  fasting_PH_C  9179       19
#
#                                         column_names
# 0  [SEQN, WTSAF2YR, LBXGLU, LBDGLUSI, LBXCPSI, LB...
# 1           [SEQN, LBXTC, LBXHDD, LBDTCSI, LBDHDDSI]
# 2  [SEQN, PHQ020, PHACOFHR, PHACOFMN, PHQ030, PHA...
# ==================================================
# FILE: glucose_cpep_insulin_L10AM_C
# COLUMNS: 7
# ['SEQN', 'WTSAF2YR', 'LBXGLU', 'LBDGLUSI', 'LBXCPSI', 'LBXIN', 'LBDINSI']
#
# ==================================================
# FILE: cholesterol_L13_C
# COLUMNS: 5
# ['SEQN', 'LBXTC', 'LBXHDD', 'LBDTCSI', 'LBDHDDSI']
#
# ==================================================
# FILE: fasting_PH_C
# COLUMNS: 19
# ['SEQN', 'PHQ020', 'PHACOFHR', 'PHACOFMN', 'PHQ030', 'PHAALCHR', 'PHAALCMN', 'PHQ040', 'PHAGUMHR', 'PHAGUMMN', 'PHQ050', 'PHAANTHR', 'PHAANTMN', 'PHQ060', 'PHASUPHR', 'PHASUPMN', 'PHAFSTHR', 'PHAFSTMN', 'PHDSESN']
#        SEQN  WTSAF2YR  LBXGLU  LBDGLUSI  LBXCPSI  LBXIN  LBDINSI  \
# 0   21005.0  14084.10    87.6     4.863    0.591  11.26    67.56
# 1   21006.0  13080.94    75.0     4.163    0.535  11.44    68.64
# 2   21007.0       NaN     NaN       NaN      NaN    NaN      NaN
# 3   21008.0       NaN     NaN       NaN      NaN    NaN      NaN
# 4   21009.0       NaN     NaN       NaN      NaN    NaN      NaN
# 5   21010.0       NaN     NaN       NaN      NaN    NaN      NaN
# 6   21012.0       NaN     NaN       NaN      NaN    NaN      NaN
# 7   21013.0  17173.77    91.7     5.090    0.593  10.63    63.78
# 8   21014.0       NaN     NaN       NaN      NaN    NaN      NaN
# 9   21015.0       NaN     NaN       NaN      NaN    NaN      NaN
# 10  21016.0  17008.13    79.3     4.402    0.619  16.45    98.70
# 11  21017.0       NaN     NaN       NaN      NaN    NaN      NaN
# 12  21018.0       NaN     NaN       NaN      NaN    NaN      NaN
# 13  21019.0       NaN     NaN       NaN      NaN    NaN      NaN
# 14  21020.0  65607.89    88.1     4.890    0.717   9.05    54.30
# 15  21022.0       NaN     NaN       NaN      NaN    NaN      NaN
# 16  21023.0       NaN     NaN       NaN      NaN    NaN      NaN
# 17  21024.0       NaN     NaN       NaN      NaN    NaN      NaN
# 18  21025.0  33084.63    85.6     4.752    0.447   3.22    19.32
# 19  21026.0       NaN     NaN       NaN      NaN    NaN      NaN
#
#    SEQN_in_glucose_cpep_insulin  LBXTC  LBXHDD  ...  PHQ060  PHASUPHR  \
# 0                          True  189.0    44.0  ...     2.0       NaN
# 1                          True  159.0    53.0  ...     2.0       NaN
# 2                           NaN  212.0    69.0  ...     2.0       NaN
# 3                           NaN  175.0    66.0  ...     2.0       NaN
# 4                           NaN  254.0    37.0  ...     2.0       NaN
# 5                           NaN  174.0   119.0  ...     2.0       NaN
# 6                           NaN  191.0    92.0  ...     2.0       NaN
# 7                          True  171.0    69.0  ...     2.0       NaN
# 8                           NaN    NaN     NaN  ...     2.0       NaN
# 9                           NaN  141.0    34.0  ...     2.0       NaN
# 10                         True  153.0    43.0  ...     2.0       NaN
# 11                          NaN  184.0    77.0  ...     2.0       NaN
# 12                          NaN    NaN     NaN  ...     NaN       NaN
# 13                          NaN  173.0    45.0  ...     2.0       NaN
# 14                         True  230.0    51.0  ...     2.0       NaN
# 15                          NaN    NaN     NaN  ...     2.0       NaN
# 16                          NaN  192.0    53.0  ...     2.0       NaN
# 17                          NaN  125.0    33.0  ...     2.0       NaN
# 18                         True  183.0    62.0  ...     2.0       NaN
# 19                          NaN  137.0    36.0  ...     2.0       NaN
#
#    PHASUPMN      PHAFSTHR      PHAFSTMN       PHDSESN  SEQN_in_fasting  \
# 0       NaN  1.000000e+01  2.000000e+00  5.397605e-79             True
# 1       NaN  1.200000e+01  2.200000e+01  5.397605e-79             True
# 2       NaN  2.000000e+01  5.500000e+01  1.000000e+00             True
# 3       NaN  4.000000e+00  3.500000e+01  1.000000e+00             True
# 4       NaN  6.000000e+00  1.500000e+01  1.000000e+00             True
# 5       NaN  7.000000e+00  1.200000e+01  1.000000e+00             True
# 6       NaN  1.400000e+01  3.200000e+01  1.000000e+00             True
# 7       NaN  1.200000e+01  1.700000e+01  5.397605e-79             True
# 8       NaN  1.100000e+01  5.900000e+01  5.397605e-79             True
# 9       NaN  1.400000e+01  1.300000e+01  1.000000e+00             True
# 10      NaN  1.400000e+01  1.500000e+01  5.397605e-79             True
# 11      NaN  2.000000e+01  4.700000e+01  1.000000e+00             True
# 12      NaN           NaN           NaN  2.000000e+00             True
# 13      NaN  8.000000e+00  1.000000e+00  1.000000e+00             True
# 14      NaN  1.400000e+01  1.900000e+01  5.397605e-79             True
# 15      NaN  5.397605e-79  1.500000e+01  2.000000e+00             True
# 16      NaN  7.000000e+00  2.500000e+01  2.000000e+00             True
# 17      NaN  1.900000e+01  1.000000e+00  1.000000e+00             True
# 18      NaN  1.600000e+01  5.397605e-79  5.397605e-79             True
# 19      NaN  1.400000e+01  7.000000e+00  1.000000e+00             True
#
#     present_glucose_cpep_insulin  present_chol  present_fasting
# 0                           True          True             True
# 1                           True          True             True
# 2                          False          True             True
# 3                          False          True             True
# 4                          False          True             True
# 5                          False          True             True
# 6                          False          True             True
# 7                           True          True             True
# 8                          False          True             True
# 9                          False          True             True
# 10                          True          True             True
# 11                         False          True             True
# 12                         False          True             True
# 13                         False          True             True
# 14                          True          True             True
# 15                         False         False             True
# 16                         False          True             True
# 17                         False          True             True
# 18                          True          True             True
# 19                         False          True             True
#
# [20 rows x 35 columns]
# Unique SEQN count: 9179
# 📋 Final Columns After Merge + Rename:
# ['SEQN', 'WTSAF2YR_fasting_subsample_weight_2yr', 'LBXGLU_plasma_glucose_mg_dl', 'LBDGLUSI_plasma_glucose_mmol_l', 'LBXCPSI_c_peptide_si_nmol_l', 'LBXIN_insulin_uu_ml', 'LBDINSI_insulin_si_pmol_l', 'SEQN_in_glucose_cpep_insulin', 'LBXTC_total_cholesterol_mg_dl', 'LBXHDD_hdl_cholesterol_mg_dl', 'LBDTCSI_total_cholesterol_mmol_l', 'LBDHDDSI_hdl_cholesterol_mmol_l', 'SEQN_in_chol', 'PHQ020_coffee_tea_consumption_code', 'PHACOFHR_coffee_tea_fast_hours', 'PHACOFMN_coffee_tea_fast_minutes', 'PHQ030_alcohol_consumption_code', 'PHAALCHR_alcohol_fast_hours', 'PHAALCMN_alcohol_fast_minutes', 'PHQ040_gum_mint_cough_consumption_code', 'PHAGUMHR_gum_mint_fast_hours', 'PHAGUMMN_gum_mint_fast_minutes', 'PHQ050_antacid_laxative_consumption_code', 'PHAANTHR_antacid_fast_hours', 'PHAANTMN_antacid_fast_minutes', 'PHQ060_supplement_consumption_code', 'PHASUPHR_supplement_fast_hours', 'PHASUPMN_supplement_fast_minutes', 'PHAFSTHR_total_fast_hours', 'PHAFSTMN_total_fast_minutes', 'PHDSESN_exam_session', 'SEQN_in_fasting', 'present_glucose_cpep_insulin', 'present_chol', 'present_fasting']
#
# 📊 Shape: (9179, 35)
#
# ✅ Saved to:
# C:\Users\NVK00\Desktop\MyData\Projects\Clinical_Neighbourhood_ML_Data_Predictor\data\processed\neighbourhood_nhanes_labs_2003_2004.csv
