# %%
# =================================================================================================
# PART 1 - Demographics part one will aggregate all data into 1 file
# Raw data : This is All Demographics data from NHANES
# Previously Done : To run this file, the list of CSVs below have processed datasets yearly into saperate notebooks
# Purpose : This Aggregator program combining all Demographics data 2004-2014 into one as below will get all yearly csvs and create one dataset file 2003-2014 
# Specification : Each NHANE dataset has SEQN "Participent ID" which is uniqud id for labs. 
# Files Used :  DEMO_C.csv, DEMO_D.csv, DEMO_E.csv,DEMO_F.csv, DEMO_G.csv, DEMO_H.csv
# Data Availability Matrix : https://docs.google.com/spreadsheets/d/1E_zIzHZsEs0o-XWx8HbTN7ZPODge7EEC/edit?gid=1721397761#gid=1721397761
# Source Site : https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public
# Developer Notes :  The notebook had created for windows desktop environment with Python3.
# File Creator : Neha Khairnar
# ===================================================================================================
# 📦 Step 1: Imports
# =========================
import pandas as pd
from pathlib import Path

# =========================
# 📂 Step 2: Define Paths
# =========================
BASE_DIR = Path().resolve().parent
DATA_DIR = BASE_DIR / "data" / "2013_2014" / "Demographics"

# List all demographic files (update names as per your files)
FILES = [
    "DEMO_H_corrected.csv",
    # "DEMO_D.csv",
    # "DEMO_E.csv",
    # "DEMO_F.csv",
    # "DEMO_G.csv",
    # "DEMO_H.csv"
]


# =========================
# 📥 Step 3: Load & Append
# =========================
dfs = []
for file in FILES:
    path = DATA_DIR / file
    #df = pd.read_csv(path)  
    
    df = pd.read_csv(
        path,
        dtype=str,
        keep_default_na=False
    )

    # Standardize column names
    df.columns = df.columns.str.upper()
    # Optional: Add survey cycle column
    if file == "DEMO_H_corrected.csv":
        df["CYCLE"] = "2013-2014"
        df["Source"] = "DEMO_H"
    print(file, "shape:", df.shape)
    dfs.append(df)


# =========================
# 🔗 Step 4: Concatenate (Append)
# =========================
demo_all = pd.concat(dfs, axis=0, ignore_index=True)

# =========================
# 👀 Step 5: Preview
# =========================
print("Combined Demographics Preview:")
display(demo_all.head(10))

# =========================
# 📊 Step 6: Validation
# =========================
print("Final shape:", demo_all.shape)

# Check duplicate SEQN (should be unique across cycles)
duplicates = demo_all["SEQN"].duplicated().sum()
print("Duplicate SEQN:", duplicates)

# =========================
# 🧼 Step 7: Optional Cleaning
# =========================
# Drop exact duplicates if any
demo_all = demo_all.drop_duplicates()

# =========================
# 💾 Step 8: Save Output
# =========================
OUTPUT_DIR = BASE_DIR / "data" / "processed_v3/2013_2014"
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)

demo_all.to_csv(OUTPUT_DIR / "neighbourhood_nhanes_demographics_2013_2014_raw_corrected.csv", index=False)

print("Saved to:")
print(OUTPUT_DIR / "neighbourhood_nhanes_demographics_2013_2014_raw_corrected.csv")
# Out:
# DEMO_H_corrected.csv shape: (10175, 49)
# Combined Demographics Preview:
#     SEQN SDDSRVYR RIDSTATR RIAGENDR RIDAGEYR RIDAGEMN RIDRETH1 RIDRETH3  \
# 0  73557        8        2        1       69                 4        4
# 1  73558        8        2        1       54                 3        3
# 2  73559        8        2        1       72                 3        3
# 3  73560        8        2        1        9                 3        3
# 4  73561        8        2        2       73                 3        3
# 5  73562        8        2        1       56                 1        1
# 6  73563        8        2        1        0        5        3        3
# 7  73564        8        2        2       61                 3        3
# 8  73565        8        1        1       42                 2        2
# 9  73566        8        2        2       56                 3        3
#
#   RIDEXMON RIDEXAGM  ... DMDHSEDU      WTINT2YR      WTMEC2YR SDMVPSU  \
# 0        1           ...           13281.237386  13481.042095       1
# 1        1           ...        1  23682.057386  24471.769625       1
# 2        2           ...        3  57214.803319  57193.285376       1
# 3        1      119  ...        4  55201.178592  55766.512438       2
# 4        1           ...        5  63709.667069  65541.871229       2
# 5        1           ...           24978.144602  25344.992359       1
# 6        2        6  ...        5  18040.818432  17913.555067       1
# 7        2           ...           60325.095254   61758.65488       1
# 8                    ...        5  23307.675629           0.0       2
# 9        1           ...            16351.78314  17480.115175       1
#
#   SDMVSTRA INDHHIN2 INDFMIN2 INDFMPIR      CYCLE  Source
# 0      112        4        4     0.84  2013-2014  DEMO_H
# 1      108        7        7     1.78  2013-2014  DEMO_H
# 2      109       10       10     4.51  2013-2014  DEMO_H
# 3      109        9        9     2.52  2013-2014  DEMO_H
# 4      116       15       15      5.0  2013-2014  DEMO_H
# 5      111        9        9     4.79  2013-2014  DEMO_H
# 6      105       15       15      5.0  2013-2014  DEMO_H
# 7      114       10       10      5.0  2013-2014  DEMO_H
# 8      106       15       15      5.0  2013-2014  DEMO_H
# 9      112        4        4     0.48  2013-2014  DEMO_H
#
# [10 rows x 49 columns]
# Final shape: (10175, 49)
# Duplicate SEQN: 0
# Saved to:
# C:\Users\User\Desktop\Projects\Clinical_Neighbourhood_ML_Data_Predictor\Clinical_Neighbourhood_ML_Data_Predictor\data\processed_v3\2013_2014\neighbourhood_nhanes_demographics_2013_2014_raw_corrected.csv
